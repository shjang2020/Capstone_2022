# %%
import tensorflow as tf
import random
import os
import pickle
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
def seed_everything(seed: int = 42):
    random.seed(seed)
    np.random.seed(seed)
    os.environ["PYTHONHASHSEED"] = str(seed)
    tf.random.set_seed(seed)

seed_everything(42)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip -qq "/content/drive/MyDrive/Colab Notebooks/캡스톤/data/food_3.zip"

# %%
with open("./food_3/train_id_data.pickle","rb") as fr:
    train_data = pickle.load(fr)
    
with open("./food_3/valid_id_data.pickle","rb") as fr:
    valid_data = pickle.load(fr)
    
with open("./food_3/test_id_data.pickle","rb") as fr:
    test_data = pickle.load(fr)

# %%
with open("./food_3/train_target.pickle","rb") as fr:
    train_target = pickle.load(fr)
    
with open("./food_3/valid_target.pickle","rb") as fr:
    valid_target = pickle.load(fr)
    
with open("./food_3/test_target.pickle","rb") as fr:
    test_target = pickle.load(fr)

# %%
# ID
train_data[0] = tf.convert_to_tensor(train_data[0], dtype=tf.float32)
train_data[1] = tf.convert_to_tensor(train_data[1], dtype=tf.float32)

# %% [markdown]
# ## Model

# %%
from tensorflow import keras
from keras.layers import Input, Embedding, LSTM, Dense, Lambda, Multiply, Bidirectional, Flatten, BatchNormalization, Add, Multiply
from keras.layers.convolutional import Conv1D
from keras.layers.pooling import MaxPool1D
from keras.models import Model
from keras.layers.wrappers import TimeDistributed
import numpy as np
import keras.backend as K
from random import randint

import os
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
description_num = 3
#current_path ='data/'
#local_path = 'data/'

# %%
# set parameters:
# V = 142381
# V = 226928
V = 74258 #  33531 6158 48456
embedding_dim = 50
max_len = 1 #  1945 77 1
filters_num = 64
kernel_size_1 = 3
kernel_size_2 = 5
kernel_size_3 = 7

# %%
# description_input=Input(shape=(10,50))
# description_validation=Input(shape=(50,))
input_1 = Input(shape=(description_num, max_len))
input_2 = Input(shape=(max_len,))
embedding = Embedding(input_dim=V,
                      output_dim=embedding_dim,
                      input_length=max_len)
conv1d_1 = Conv1D(filters=filters_num,
                kernel_size=kernel_size_1,
                activation='relu',
                padding='same')
conv1d_2 = Conv1D(filters=filters_num,
                kernel_size=kernel_size_2,
                activation='relu',
                padding='same')
conv1d_3 = Conv1D(filters=filters_num,
                kernel_size=kernel_size_3,
                activation='relu',
                padding='same')
maxpool1d = MaxPool1D(max_len)
dense = Dense(15)

# input_vector=TimeDistributed(embedding)(description_input)
# validation_vector=embedding(description_validation)

input_vector = TimeDistributed(embedding)(input_1)
validation_vector = embedding(input_2)

convolutional_vector_1 = TimeDistributed(conv1d_1)(input_vector)
validation_conv_1 = conv1d_1(validation_vector)

convolutional_vector_2 = TimeDistributed(conv1d_2)(input_vector)
validation_conv_2 = conv1d_2(validation_vector)

convolutional_vector_3 = TimeDistributed(conv1d_3)(input_vector)
validation_conv_3 = conv1d_3(validation_vector)

convolutional_merge = Multiply()([convolutional_vector_1, convolutional_vector_2, convolutional_vector_3])
validation_merge = Multiply()([validation_conv_1, validation_conv_2, validation_conv_3])

maxpooling_vector = TimeDistributed(maxpool1d)(convolutional_merge)
validation_maxpooling = maxpool1d(validation_merge)

middle_output = TimeDistributed(dense)(maxpooling_vector)
middle_validation = dense(validation_maxpooling)

# %%
print(input_vector.shape, validation_vector.shape,
      convolutional_vector_1.shape, validation_conv_1.shape,
      maxpooling_vector.shape, validation_maxpooling.shape,
      middle_output.shape, middle_validation.shape)
# Out:
# (None, 3, 1, 50) (None, 1, 50) (None, 3, 1, 64) (None, 1, 64) (None, 3, 1, 64) (None, 1, 64) (None, 3, 1, 15) (None, 1, 15)

# %%
def change_dim_1(X):
    return K.squeeze(X, 1)

def change_dim_2(X):
    return K.squeeze(X, 2)

def repeat(X):
    return K.repeat_elements(X, description_num, 1)

def repeat1(X):
    return K.repeat_elements(X, 15, 2)

def repeat2(X):
    return K.repeat_elements(X, description_num, 1)

def dot(X, Y):
    return K.dot(X, Y)

def sum_item(X):
    return K.sum(X, axis=2)

def sqrt_item(X):
    return K.sqrt(X)

def cal_denominator(X):
    return 1/(X)

def expand_item(X):
    return K.expand_dims(X, 2)

def expand_rate(X):
    return K.expand_dims(X, 1)

def sum_user(X):
    return K.sum(X, 1)

def sum_rate(X):
    return K.sum(X, 1)

def single_exp(X):
    return K.exp(X)

def sum_exp_denominator(X):
    return 1/(K.sum(K.exp(X), 1))

# %%
# def _test_generator(filename):

middle_output_final = Lambda(change_dim_2)(middle_output)#?*10*15
middle_validation_final = Lambda(repeat)(middle_validation)#?*10*15
molecule = Multiply()([middle_output_final, middle_validation_final])
molecule = Lambda(sum_item)(molecule)

denominator1 = Multiply()([middle_output_final, middle_output_final])
denominator1 = Lambda(sum_item)(denominator1)
denominator1 = Lambda(sqrt_item)(denominator1)

denominator2 = Multiply()([middle_validation_final, middle_validation_final])
denominator2 = Lambda(sum_item)(denominator2)
denominator2 = Lambda(sqrt_item)(denominator2)


denominator = Multiply()([denominator1, denominator2])
denominator = Lambda(cal_denominator)(denominator)

similarity = Multiply()([molecule, denominator])
similarity = Lambda(expand_item)(similarity)
similarity = Lambda(repeat1)(similarity)


user = Multiply()([similarity, middle_output_final])
user = Lambda(sum_user)(user)


item = Lambda(change_dim_1)(middle_validation)


rate_hat = Multiply()([user, item])
rate_hat = Lambda(sum_rate)(rate_hat)
rate_hat = Lambda(expand_rate)(rate_hat)

# %%
model = Model(inputs=[input_1, input_2], outputs=rate_hat)
model.compile(optimizer='adam', loss='mae', metrics=['mse', 'mae', 'mape'])

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 3, 1)]       0           []
#
#  input_2 (InputLayer)           [(None, 1)]          0           []
#
#  time_distributed (TimeDistribu  (None, 3, 1, 50)    3712900     ['input_1[0][0]']
#  ted)
#
#  embedding (Embedding)          (None, 1, 50)        3712900     ['input_2[0][0]']
#
#  time_distributed_1 (TimeDistri  (None, 3, 1, 64)    9664        ['time_distributed[0][0]']
#  buted)
#
#  time_distributed_2 (TimeDistri  (None, 3, 1, 64)    16064       ['time_distributed[0][0]']
#  buted)
#
#  time_distributed_3 (TimeDistri  (None, 3, 1, 64)    22464       ['time_distributed[0][0]']
#  buted)
#
#  conv1d (Conv1D)                (None, 1, 64)        9664        ['embedding[0][0]']
#
#  conv1d_1 (Conv1D)              (None, 1, 64)        16064       ['embedding[0][0]']
#
#  conv1d_2 (Conv1D)              (None, 1, 64)        22464       ['embedding[0][0]']
#
#  multiply (Multiply)            (None, 3, 1, 64)     0           ['time_distributed_1[0][0]',
#                                                                   'time_distributed_2[0][0]',
#                                                                   'time_distributed_3[0][0]']
#
#  multiply_1 (Multiply)          (None, 1, 64)        0           ['conv1d[0][0]',
#                                                                   'conv1d_1[0][0]',
#                                                                   'conv1d_2[0][0]']
#
#  time_distributed_4 (TimeDistri  (None, 3, 1, 64)    0           ['multiply[0][0]']
#  buted)
#
#  max_pooling1d (MaxPooling1D)   (None, 1, 64)        0           ['multiply_1[0][0]']
#
#  time_distributed_5 (TimeDistri  (None, 3, 1, 15)    975         ['time_distributed_4[0][0]']
#  buted)
#
#  dense (Dense)                  (None, 1, 15)        975         ['max_pooling1d[0][0]']
#
#  lambda (Lambda)                (None, 3, 15)        0           ['time_distributed_5[0][0]']
#
#  lambda_1 (Lambda)              (None, 3, 15)        0           ['dense[0][0]']
#
#  multiply_3 (Multiply)          (None, 3, 15)        0           ['lambda[0][0]',
#                                                                   'lambda[0][0]']
#
#  multiply_4 (Multiply)          (None, 3, 15)        0           ['lambda_1[0][0]',
#                                                                   'lambda_1[0][0]']
#
#  lambda_3 (Lambda)              (None, 3)            0           ['multiply_3[0][0]']
#
#  lambda_5 (Lambda)              (None, 3)            0           ['multiply_4[0][0]']
#
#  lambda_4 (Lambda)              (None, 3)            0           ['lambda_3[0][0]']
#
#  lambda_6 (Lambda)              (None, 3)            0           ['lambda_5[0][0]']
#
#  multiply_2 (Multiply)          (None, 3, 15)        0           ['lambda[0][0]',
#                                                                   'lambda_1[0][0]']
#
#  multiply_5 (Multiply)          (None, 3)            0           ['lambda_4[0][0]',
#                                                                   'lambda_6[0][0]']
#
#  lambda_2 (Lambda)              (None, 3)            0           ['multiply_2[0][0]']
#
#  lambda_7 (Lambda)              (None, 3)            0           ['multiply_5[0][0]']
#
#  multiply_6 (Multiply)          (None, 3)            0           ['lambda_2[0][0]',
#                                                                   'lambda_7[0][0]']
#
#  lambda_8 (Lambda)              (None, 3, 1)         0           ['multiply_6[0][0]']
#
#  lambda_9 (Lambda)              (None, 3, 15)        0           ['lambda_8[0][0]']
#
#  multiply_7 (Multiply)          (None, 3, 15)        0           ['lambda_9[0][0]',
#                                                                   'lambda[0][0]']
#
#  lambda_10 (Lambda)             (None, 15)           0           ['multiply_7[0][0]']
#
#  lambda_11 (Lambda)             (None, 15)           0           ['dense[0][0]']
#
#  multiply_8 (Multiply)          (None, 15)           0           ['lambda_10[0][0]',
#                                                                   'lambda_11[0][0]']
#
#  lambda_12 (Lambda)             (None,)              0           ['multiply_8[0][0]']
#
#  lambda_13 (Lambda)             (None, 1)            0           ['lambda_12[0][0]']
#
# ==================================================================================================
# Total params: 3,762,067
# Trainable params: 3,762,067
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
hist = model.fit(train_data, train_target,
                 validation_data=(valid_data, valid_target),
                 steps_per_epoch=256,
                 validation_steps=256,
                 epochs=30,
                 verbose=1)
# Out:
# Epoch 1/30
# 256/256 [==============================] - 16s 13ms/step - loss: 2.2292 - mse: 8.3280 - mae: 2.2292 - mape: 66.9687 - val_loss: 0.8021 - val_mse: 2.1162 - val_mae: 0.8021 - val_mape: 49.8065
# Epoch 2/30
# 256/256 [==============================] - 3s 12ms/step - loss: 0.7786 - mse: 2.0129 - mae: 0.7786 - mape: 48.6495 - val_loss: 0.8548 - val_mse: 1.9714 - val_mae: 0.8548 - val_mape: 47.5342
# Epoch 3/30
# 256/256 [==============================] - 3s 11ms/step - loss: 0.7161 - mse: 1.7567 - mae: 0.7161 - mape: 43.3720 - val_loss: 0.8401 - val_mse: 1.9831 - val_mae: 0.8401 - val_mape: 46.9232
# Epoch 4/30
# 256/256 [==============================] - 3s 11ms/step - loss: 0.6880 - mse: 1.6784 - mae: 0.6880 - mape: 41.7533 - val_loss: 0.8531 - val_mse: 1.9765 - val_mae: 0.8531 - val_mape: 46.3435
# Epoch 5/30
# 256/256 [==============================] - 3s 11ms/step - loss: 0.6764 - mse: 1.6322 - mae: 0.6764 - mape: 40.7057 - val_loss: 0.8569 - val_mse: 1.9880 - val_mae: 0.8569 - val_mape: 46.4760
# Epoch 6/30
# 256/256 [==============================] - 3s 11ms/step - loss: 0.6681 - mse: 1.6125 - mae: 0.6681 - mape: 40.2218 - val_loss: 0.8667 - val_mse: 2.0196 - val_mae: 0.8667 - val_mape: 46.4075
# Epoch 7/30
# 256/256 [==============================] - 3s 11ms/step - loss: 0.6628 - mse: 1.5927 - mae: 0.6628 - mape: 39.7928 - val_loss: 0.8717 - val_mse: 2.0235 - val_mae: 0.8717 - val_mape: 46.5034
# Epoch 8/30
# 256/256 [==============================] - 3s 11ms/step - loss: 0.6583 - mse: 1.5783 - mae: 0.6583 - mape: 39.4738 - val_loss: 0.8799 - val_mse: 2.0270 - val_mae: 0.8799 - val_mape: 46.4112
# Epoch 9/30
# 256/256 [==============================] - 3s 11ms/step - loss: 0.6524 - mse: 1.5660 - mae: 0.6524 - mape: 39.1469 - val_loss: 0.8868 - val_mse: 2.0358 - val_mae: 0.8868 - val_mape: 46.2870
# Epoch 10/30
# 256/256 [==============================] - 3s 11ms/step - loss: 0.6485 - mse: 1.5557 - mae: 0.6485 - mape: 38.8999 - val_loss: 0.8856 - val_mse: 2.0150 - val_mae: 0.8856 - val_mape: 46.2265
# Epoch 11/30
# 256/256 [==============================] - 3s 11ms/step - loss: 0.6454 - mse: 1.5452 - mae: 0.6454 - mape: 38.6444 - val_loss: 0.8939 - val_mse: 2.0514 - val_mae: 0.8939 - val_mape: 46.4110
# Epoch 12/30
# 256/256 [==============================] - 3s 11ms/step - loss: 0.6416 - mse: 1.5411 - mae: 0.6416 - mape: 38.4288 - val_loss: 0.8923 - val_mse: 2.0386 - val_mae: 0.8923 - val_mape: 46.3277
# Epoch 13/30
# 256/256 [==============================] - 3s 11ms/step - loss: 0.6410 - mse: 1.5305 - mae: 0.6410 - mape: 38.3001 - val_loss: 0.9003 - val_mse: 2.0620 - val_mae: 0.9003 - val_mape: 46.3087
# Epoch 14/30
# 256/256 [==============================] - 3s 11ms/step - loss: 0.6375 - mse: 1.5283 - mae: 0.6375 - mape: 38.1096 - val_loss: 0.9039 - val_mse: 2.0551 - val_mae: 0.9039 - val_mape: 46.1934
# Epoch 15/30
# 256/256 [==============================] - 3s 11ms/step - loss: 0.6360 - mse: 1.5221 - mae: 0.6360 - mape: 37.9536 - val_loss: 0.9062 - val_mse: 2.0694 - val_mae: 0.9062 - val_mape: 46.3618
# Epoch 16/30
# 256/256 [==============================] - 3s 11ms/step - loss: 0.6332 - mse: 1.5183 - mae: 0.6332 - mape: 37.8210 - val_loss: 0.9080 - val_mse: 2.0652 - val_mae: 0.9080 - val_mape: 46.2274
# Epoch 17/30
# 256/256 [==============================] - 3s 11ms/step - loss: 0.6324 - mse: 1.5142 - mae: 0.6324 - mape: 37.6916 - val_loss: 0.9093 - val_mse: 2.0600 - val_mae: 0.9093 - val_mape: 46.2612
# Epoch 18/30
# 256/256 [==============================] - 3s 11ms/step - loss: 0.6304 - mse: 1.5108 - mae: 0.6304 - mape: 37.5860 - val_loss: 0.9049 - val_mse: 2.0694 - val_mae: 0.9049 - val_mape: 46.3062
# Epoch 19/30
# 256/256 [==============================] - 3s 11ms/step - loss: 0.6286 - mse: 1.5085 - mae: 0.6286 - mape: 37.5054 - val_loss: 0.9106 - val_mse: 2.0708 - val_mae: 0.9106 - val_mape: 46.2208
# Epoch 20/30
# 256/256 [==============================] - 3s 11ms/step - loss: 0.6277 - mse: 1.5066 - mae: 0.6277 - mape: 37.4349 - val_loss: 0.9110 - val_mse: 2.0863 - val_mae: 0.9110 - val_mape: 46.3261
# Epoch 21/30
# 256/256 [==============================] - 3s 11ms/step - loss: 0.6278 - mse: 1.5020 - mae: 0.6278 - mape: 37.3618 - val_loss: 0.9114 - val_mse: 2.0753 - val_mae: 0.9114 - val_mape: 46.2812
# Epoch 22/30
# 256/256 [==============================] - 3s 11ms/step - loss: 0.6248 - mse: 1.5027 - mae: 0.6248 - mape: 37.2886 - val_loss: 0.9099 - val_mse: 2.0701 - val_mae: 0.9099 - val_mape: 46.2674
# Epoch 23/30
# 256/256 [==============================] - 3s 11ms/step - loss: 0.6235 - mse: 1.5004 - mae: 0.6235 - mape: 37.2066 - val_loss: 0.9061 - val_mse: 2.0760 - val_mae: 0.9061 - val_mape: 46.3314
# Epoch 24/30
# 256/256 [==============================] - 3s 11ms/step - loss: 0.6239 - mse: 1.4981 - mae: 0.6239 - mape: 37.1814 - val_loss: 0.9074 - val_mse: 2.0830 - val_mae: 0.9074 - val_mape: 46.3387
# Epoch 25/30
# 256/256 [==============================] - 3s 11ms/step - loss: 0.6215 - mse: 1.4989 - mae: 0.6215 - mape: 37.1081 - val_loss: 0.9089 - val_mse: 2.0752 - val_mae: 0.9089 - val_mape: 46.1788
# Epoch 26/30
# 256/256 [==============================] - 3s 11ms/step - loss: 0.6223 - mse: 1.4949 - mae: 0.6223 - mape: 37.0485 - val_loss: 0.9097 - val_mse: 2.0873 - val_mae: 0.9097 - val_mape: 46.4446
# Epoch 27/30
# 256/256 [==============================] - 3s 11ms/step - loss: 0.6204 - mse: 1.4963 - mae: 0.6204 - mape: 37.0130 - val_loss: 0.9040 - val_mse: 2.0662 - val_mae: 0.9040 - val_mape: 46.2854
# Epoch 28/30
# 256/256 [==============================] - 3s 11ms/step - loss: 0.6189 - mse: 1.4966 - mae: 0.6189 - mape: 36.9675 - val_loss: 0.9047 - val_mse: 2.0840 - val_mae: 0.9047 - val_mape: 46.3759
# Epoch 29/30
# 256/256 [==============================] - 3s 11ms/step - loss: 0.6186 - mse: 1.4946 - mae: 0.6186 - mape: 36.9212 - val_loss: 0.9032 - val_mse: 2.0759 - val_mae: 0.9032 - val_mape: 46.3166
# Epoch 30/30
# 256/256 [==============================] - 3s 11ms/step - loss: 0.6177 - mse: 1.4933 - mae: 0.6177 - mape: 36.8861 - val_loss: 0.9061 - val_mse: 2.0833 - val_mae: 0.9061 - val_mape: 46.4105

# %%
# scores = model.evaluate_generator(_evaluate_generator('train_whole_list_5s.txt','test_whole_list_5s.txt'),steps=134103)
# scores = model.evaluate_generator(_evaluate_generator('train_whole_list_10.txt','test_whole_list_10.txt'),steps=34266)
# scores = model.evaluate_generator(_evaluate_generator('train_whole_list_6s.txt','test_whole_list_6s.txt'),steps=134103)
scores = model.evaluate(test_data, test_target, steps=2500)
print(scores)
# Out:
# 2244/2500 [=========================>....] - ETA: 0s - loss: 0.9164 - mse: 2.1114 - mae: 0.9164 - mape: 47.1612WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 2500 batches). You may need to use the repeat() function when building your dataset.
# 2500/2500 [==============================] - 7s 3ms/step - loss: 0.9161 - mse: 2.1099 - mae: 0.9161 - mape: 47.1234
# [0.916146993637085, 2.109896421432495, 0.9161471128463745, 47.12337112426758]

# %%
# model.save('/content/drive/MyDrive/Colab Notebooks/캡스톤/IMDB_ADLFM_Multi_conv1d')
