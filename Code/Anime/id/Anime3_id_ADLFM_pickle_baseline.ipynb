# %%
import tensorflow as tf
import random
import os
import pickle
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
def seed_everything(seed: int = 42):
    random.seed(seed)
    np.random.seed(seed)
    os.environ["PYTHONHASHSEED"] = str(seed)
    tf.random.set_seed(seed)

seed_everything(42)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = '/content/drive/MyDrive/Colab Notebooks/캡스톤/data/Anime3/'

# %%
with open(path+"train_id_data.pickle","rb") as fr:
    train_data = pickle.load(fr)
    
with open(path+"valid_id_data.pickle","rb") as fr:
    valid_data = pickle.load(fr)
    
with open(path+"test_id_data.pickle","rb") as fr:
    test_data = pickle.load(fr)

# %%
with open(path+"train_target.pickle","rb") as fr:
    train_target = pickle.load(fr)
    
with open(path+"valid_target.pickle","rb") as fr:
    valid_target = pickle.load(fr)
    
with open(path+"test_target.pickle","rb") as fr:
    test_target = pickle.load(fr)

# %%
test_data[0]
# Out:
# array([[[    1],
#         [33486],
#         [36456]],
#
#        [[    1],
#         [33486],
#         [36456]],
#
#        [[    1],
#         [33486],
#         [36456]],
#
#        ...,
#
#        [[34134],
#         [27899],
#         [37779]],
#
#        [[34134],
#         [27899],
#         [37779]],
#
#        [[34134],
#         [27899],
#         [37779]]])

# %% [markdown]
# ## Model

# %%
from tensorflow import keras
from keras.layers import Input, Embedding, LSTM, Dense, Lambda, Multiply, Bidirectional, Flatten, BatchNormalization, Add
from keras.layers.convolutional import Conv1D
from keras.layers.pooling import MaxPool1D
from keras.models import Model
from keras.layers.wrappers import TimeDistributed
import numpy as np
import keras.backend as K
from random import randint

import os
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
description_num = 3
#current_path ='data/'
#local_path = 'data/'

# %%
# set parameters:
# V = 142381
# V = 226928
V = 48456  #33531 # len(tokenizer.word_index)
embedding_dim = 50
max_len =  1   # 1945  # maxlen
filters_num = 64
kernel_size = 3

# %%
test_data[0][0]
# Out:
# array([[    1],
#        [33486],
#        [36456]])

# %%
# description_input=Input(shape=(10,50))
# description_validation=Input(shape=(50,))

input_1 = Input(shape=(description_num, max_len))
input_2 = Input(shape=(max_len,))
embedding = Embedding(input_dim=V,
                      output_dim=embedding_dim,
                      input_length=max_len)
conv1d = Conv1D(filters=filters_num,
                kernel_size=kernel_size,
                activation='relu',
                padding='same')
maxpool1d = MaxPool1D(max_len)
dense = Dense(15)

# input_vector=TimeDistributed(embedding)(description_input)
# validation_vector=embedding(description_validation)

input_vector = TimeDistributed(embedding)(input_1)
validation_vector = embedding(input_2)

convolutional_vector = TimeDistributed(conv1d)(input_vector)
validation_conv = conv1d(validation_vector)

maxpooling_vector = TimeDistributed(maxpool1d)(convolutional_vector)
validation_maxpooling = maxpool1d(validation_conv)

middle_output = TimeDistributed(dense)(maxpooling_vector)
middle_validation = dense(validation_maxpooling)

# %%
print(input_vector.shape, validation_vector.shape,
      convolutional_vector.shape, validation_conv.shape,
      maxpooling_vector.shape, validation_maxpooling.shape,
      middle_output.shape, middle_validation.shape)
# Out:
# (None, 3, 1, 50) (None, 1, 50) (None, 3, 1, 64) (None, 1, 64) (None, 3, 1, 64) (None, 1, 64) (None, 3, 1, 15) (None, 1, 15)

# %%
def change_dim_1(X):
    return K.squeeze(X, 1)

def change_dim_2(X):
    return K.squeeze(X, 2)

def repeat(X):
    return K.repeat_elements(X, description_num, 1)

def repeat1(X):
    return K.repeat_elements(X, 15, 2)

def repeat2(X):
    return K.repeat_elements(X, description_num, 1)

def dot(X, Y):
    return K.dot(X, Y)

def sum_item(X):
    return K.sum(X, axis=2)

def sqrt_item(X):
    return K.sqrt(X)

def cal_denominator(X):
    return 1/(X)

def expand_item(X):
    return K.expand_dims(X, 2)

def expand_rate(X):
    return K.expand_dims(X, 1)

def sum_user(X):
    return K.sum(X, 1)

def sum_rate(X):
    return K.sum(X, 1)

def single_exp(X):
    return K.exp(X)

def sum_exp_denominator(X):
    return 1/(K.sum(K.exp(X), 1))

# %%
# def _test_generator(filename):

middle_output_final = Lambda(change_dim_2)(middle_output)#?*10*15
middle_validation_final = Lambda(repeat)(middle_validation)#?*10*15
molecule = Multiply()([middle_output_final, middle_validation_final])
molecule = Lambda(sum_item)(molecule)

denominator1 = Multiply()([middle_output_final, middle_output_final])
denominator1 = Lambda(sum_item)(denominator1)
denominator1 = Lambda(sqrt_item)(denominator1)

denominator2 = Multiply()([middle_validation_final, middle_validation_final])
denominator2 = Lambda(sum_item)(denominator2)
denominator2 = Lambda(sqrt_item)(denominator2)


denominator = Multiply()([denominator1, denominator2])
denominator = Lambda(cal_denominator)(denominator)

similarity = Multiply()([molecule, denominator])
similarity = Lambda(expand_item)(similarity)
similarity = Lambda(repeat1)(similarity)


user = Multiply()([similarity, middle_output_final])
user = Lambda(sum_user)(user)


item = Lambda(change_dim_1)(middle_validation)


rate_hat = Multiply()([user, item])
rate_hat = Lambda(sum_rate)(rate_hat)
rate_hat = Lambda(expand_rate)(rate_hat)

# %%
model = Model(inputs=[input_1, input_2], outputs=rate_hat)
model.compile(optimizer='adam', loss='mse', metrics=['mse', 'mae', 'mape'])

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 3, 1)]       0           []
#
#  input_2 (InputLayer)           [(None, 1)]          0           []
#
#  time_distributed (TimeDistribu  (None, 3, 1, 50)    2422800     ['input_1[0][0]']
#  ted)
#
#  embedding (Embedding)          (None, 1, 50)        2422800     ['input_2[0][0]']
#
#  time_distributed_1 (TimeDistri  (None, 3, 1, 64)    9664        ['time_distributed[0][0]']
#  buted)
#
#  conv1d (Conv1D)                (None, 1, 64)        9664        ['embedding[0][0]']
#
#  time_distributed_2 (TimeDistri  (None, 3, 1, 64)    0           ['time_distributed_1[0][0]']
#  buted)
#
#  max_pooling1d (MaxPooling1D)   (None, 1, 64)        0           ['conv1d[0][0]']
#
#  time_distributed_3 (TimeDistri  (None, 3, 1, 15)    975         ['time_distributed_2[0][0]']
#  buted)
#
#  dense (Dense)                  (None, 1, 15)        975         ['max_pooling1d[0][0]']
#
#  lambda (Lambda)                (None, 3, 15)        0           ['time_distributed_3[0][0]']
#
#  lambda_1 (Lambda)              (None, 3, 15)        0           ['dense[0][0]']
#
#  multiply_1 (Multiply)          (None, 3, 15)        0           ['lambda[0][0]',
#                                                                   'lambda[0][0]']
#
#  multiply_2 (Multiply)          (None, 3, 15)        0           ['lambda_1[0][0]',
#                                                                   'lambda_1[0][0]']
#
#  lambda_3 (Lambda)              (None, 3)            0           ['multiply_1[0][0]']
#
#  lambda_5 (Lambda)              (None, 3)            0           ['multiply_2[0][0]']
#
#  lambda_4 (Lambda)              (None, 3)            0           ['lambda_3[0][0]']
#
#  lambda_6 (Lambda)              (None, 3)            0           ['lambda_5[0][0]']
#
#  multiply (Multiply)            (None, 3, 15)        0           ['lambda[0][0]',
#                                                                   'lambda_1[0][0]']
#
#  multiply_3 (Multiply)          (None, 3)            0           ['lambda_4[0][0]',
#                                                                   'lambda_6[0][0]']
#
#  lambda_2 (Lambda)              (None, 3)            0           ['multiply[0][0]']
#
#  lambda_7 (Lambda)              (None, 3)            0           ['multiply_3[0][0]']
#
#  multiply_4 (Multiply)          (None, 3)            0           ['lambda_2[0][0]',
#                                                                   'lambda_7[0][0]']
#
#  lambda_8 (Lambda)              (None, 3, 1)         0           ['multiply_4[0][0]']
#
#  lambda_9 (Lambda)              (None, 3, 15)        0           ['lambda_8[0][0]']
#
#  multiply_5 (Multiply)          (None, 3, 15)        0           ['lambda_9[0][0]',
#                                                                   'lambda[0][0]']
#
#  lambda_10 (Lambda)             (None, 15)           0           ['multiply_5[0][0]']
#
#  lambda_11 (Lambda)             (None, 15)           0           ['dense[0][0]']
#
#  multiply_6 (Multiply)          (None, 15)           0           ['lambda_10[0][0]',
#                                                                   'lambda_11[0][0]']
#
#  lambda_12 (Lambda)             (None,)              0           ['multiply_6[0][0]']
#
#  lambda_13 (Lambda)             (None, 1)            0           ['lambda_12[0][0]']
#
# ==================================================================================================
# Total params: 2,433,439
# Trainable params: 2,433,439
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
hist = model.fit(train_data, train_target,
                 validation_data=(valid_data, valid_target),
                 steps_per_epoch=256,
                 validation_steps=256,
                 epochs=30,
                 verbose=1)
# Out:
# Epoch 1/30
# 256/256 [==============================] - 16s 10ms/step - loss: 12.0991 - mse: 12.0991 - mae: 2.2746 - mape: 30.5906 - val_loss: 2.4428 - val_mse: 2.4428 - val_mae: 1.1658 - val_mape: 20.4012
# Epoch 2/30
# 256/256 [==============================] - 2s 8ms/step - loss: 2.0904 - mse: 2.0904 - mae: 1.0976 - mape: 18.2061 - val_loss: 2.3844 - val_mse: 2.3844 - val_mae: 1.1642 - val_mape: 20.1528
# Epoch 3/30
# 256/256 [==============================] - 2s 8ms/step - loss: 2.0267 - mse: 2.0267 - mae: 1.0793 - mape: 17.8550 - val_loss: 2.4407 - val_mse: 2.4407 - val_mae: 1.1496 - val_mape: 20.2517
# Epoch 4/30
# 256/256 [==============================] - 2s 8ms/step - loss: 1.9961 - mse: 1.9961 - mae: 1.0714 - mape: 17.6141 - val_loss: 2.4035 - val_mse: 2.4035 - val_mae: 1.1477 - val_mape: 20.1507
# Epoch 5/30
# 256/256 [==============================] - 2s 9ms/step - loss: 1.9784 - mse: 1.9784 - mae: 1.0657 - mape: 17.4828 - val_loss: 2.4110 - val_mse: 2.4110 - val_mae: 1.1391 - val_mape: 20.3154
# Epoch 6/30
# 256/256 [==============================] - 2s 9ms/step - loss: 1.9652 - mse: 1.9652 - mae: 1.0621 - mape: 17.3969 - val_loss: 2.4333 - val_mse: 2.4333 - val_mae: 1.1395 - val_mape: 20.3317
# Epoch 7/30
# 256/256 [==============================] - 2s 9ms/step - loss: 1.9586 - mse: 1.9586 - mae: 1.0600 - mape: 17.3418 - val_loss: 2.3971 - val_mse: 2.3971 - val_mae: 1.1615 - val_mape: 20.1128
# Epoch 8/30
# 256/256 [==============================] - 2s 8ms/step - loss: 1.9499 - mse: 1.9499 - mae: 1.0575 - mape: 17.2644 - val_loss: 2.3697 - val_mse: 2.3697 - val_mae: 1.1542 - val_mape: 20.1101
# Epoch 9/30
# 256/256 [==============================] - 2s 8ms/step - loss: 1.9398 - mse: 1.9398 - mae: 1.0547 - mape: 17.2161 - val_loss: 2.3815 - val_mse: 2.3815 - val_mae: 1.1494 - val_mape: 20.1601
# Epoch 10/30
# 256/256 [==============================] - 2s 8ms/step - loss: 1.9179 - mse: 1.9179 - mae: 1.0487 - mape: 17.1011 - val_loss: 2.4081 - val_mse: 2.4081 - val_mae: 1.1473 - val_mape: 20.2061
# Epoch 11/30
# 256/256 [==============================] - 2s 8ms/step - loss: 1.8877 - mse: 1.8877 - mae: 1.0376 - mape: 16.8931 - val_loss: 2.4156 - val_mse: 2.4156 - val_mae: 1.1583 - val_mape: 20.1593
# Epoch 12/30
# 256/256 [==============================] - 2s 8ms/step - loss: 1.8427 - mse: 1.8427 - mae: 1.0248 - mape: 16.6173 - val_loss: 2.4528 - val_mse: 2.4528 - val_mae: 1.1557 - val_mape: 20.3724
# Epoch 13/30
# 256/256 [==============================] - 2s 8ms/step - loss: 1.8069 - mse: 1.8069 - mae: 1.0131 - mape: 16.4115 - val_loss: 2.4537 - val_mse: 2.4537 - val_mae: 1.1919 - val_mape: 20.2511
# Epoch 14/30
# 256/256 [==============================] - 2s 8ms/step - loss: 1.7797 - mse: 1.7797 - mae: 1.0045 - mape: 16.2261 - val_loss: 2.5207 - val_mse: 2.5207 - val_mae: 1.1818 - val_mape: 20.4308
# Epoch 15/30
# 256/256 [==============================] - 2s 8ms/step - loss: 1.7574 - mse: 1.7574 - mae: 0.9971 - mape: 16.0938 - val_loss: 2.5014 - val_mse: 2.5014 - val_mae: 1.1940 - val_mape: 20.3417
# Epoch 16/30
# 256/256 [==============================] - 2s 9ms/step - loss: 1.7346 - mse: 1.7346 - mae: 0.9893 - mape: 15.9416 - val_loss: 2.5061 - val_mse: 2.5061 - val_mae: 1.1925 - val_mape: 20.3893
# Epoch 17/30
# 256/256 [==============================] - 2s 8ms/step - loss: 1.7063 - mse: 1.7063 - mae: 0.9803 - mape: 15.7703 - val_loss: 2.5044 - val_mse: 2.5044 - val_mae: 1.1959 - val_mape: 20.4394
# Epoch 18/30
# 256/256 [==============================] - 2s 8ms/step - loss: 1.6884 - mse: 1.6884 - mae: 0.9744 - mape: 15.6486 - val_loss: 2.5600 - val_mse: 2.5600 - val_mae: 1.1965 - val_mape: 20.5443
# Epoch 19/30
# 256/256 [==============================] - 2s 8ms/step - loss: 1.6593 - mse: 1.6593 - mae: 0.9641 - mape: 15.5000 - val_loss: 2.5870 - val_mse: 2.5870 - val_mae: 1.2138 - val_mape: 20.5651
# Epoch 20/30
# 256/256 [==============================] - 2s 8ms/step - loss: 1.6413 - mse: 1.6413 - mae: 0.9590 - mape: 15.3712 - val_loss: 2.6227 - val_mse: 2.6227 - val_mae: 1.2059 - val_mape: 20.7155
# Epoch 21/30
# 256/256 [==============================] - 2s 8ms/step - loss: 1.6204 - mse: 1.6204 - mae: 0.9515 - mape: 15.2439 - val_loss: 2.6157 - val_mse: 2.6157 - val_mae: 1.2122 - val_mape: 20.6955
# Epoch 22/30
# 256/256 [==============================] - 2s 9ms/step - loss: 1.5913 - mse: 1.5913 - mae: 0.9406 - mape: 15.0795 - val_loss: 2.6538 - val_mse: 2.6538 - val_mae: 1.2147 - val_mape: 20.7579
# Epoch 23/30
# 256/256 [==============================] - 2s 8ms/step - loss: 1.5644 - mse: 1.5644 - mae: 0.9313 - mape: 14.9267 - val_loss: 2.6449 - val_mse: 2.6449 - val_mae: 1.2201 - val_mape: 20.7388
# Epoch 24/30
# 256/256 [==============================] - 2s 9ms/step - loss: 1.5412 - mse: 1.5412 - mae: 0.9227 - mape: 14.7630 - val_loss: 2.6568 - val_mse: 2.6568 - val_mae: 1.2319 - val_mape: 20.7736
# Epoch 25/30
# 256/256 [==============================] - 2s 9ms/step - loss: 1.5252 - mse: 1.5252 - mae: 0.9176 - mape: 14.6784 - val_loss: 2.7769 - val_mse: 2.7769 - val_mae: 1.2256 - val_mape: 21.1853
# Epoch 26/30
# 256/256 [==============================] - 2s 8ms/step - loss: 1.5044 - mse: 1.5044 - mae: 0.9103 - mape: 14.5459 - val_loss: 2.7156 - val_mse: 2.7156 - val_mae: 1.2318 - val_mape: 20.9821
# Epoch 27/30
# 256/256 [==============================] - 2s 8ms/step - loss: 1.4882 - mse: 1.4882 - mae: 0.9037 - mape: 14.4331 - val_loss: 2.7448 - val_mse: 2.7448 - val_mae: 1.2596 - val_mape: 20.9953
# Epoch 28/30
# 256/256 [==============================] - 2s 8ms/step - loss: 1.4719 - mse: 1.4719 - mae: 0.8973 - mape: 14.3368 - val_loss: 2.7552 - val_mse: 2.7552 - val_mae: 1.2623 - val_mape: 20.9767
# Epoch 29/30
# 256/256 [==============================] - 2s 9ms/step - loss: 1.4639 - mse: 1.4639 - mae: 0.8955 - mape: 14.2759 - val_loss: 2.8427 - val_mse: 2.8427 - val_mae: 1.2413 - val_mape: 21.3515
# Epoch 30/30
# 256/256 [==============================] - 2s 9ms/step - loss: 1.4485 - mse: 1.4485 - mae: 0.8893 - mape: 14.1858 - val_loss: 2.7969 - val_mse: 2.7969 - val_mae: 1.2399 - val_mape: 21.2942

# %%
# scores = model.evaluate_generator(_evaluate_generator('train_whole_list_5s.txt','test_whole_list_5s.txt'),steps=134103)
# scores = model.evaluate_generator(_evaluate_generator('train_whole_list_10.txt','test_whole_list_10.txt'),steps=34266)
# scores = model.evaluate_generator(_evaluate_generator('train_whole_list_6s.txt','test_whole_list_6s.txt'),steps=134103)
scores = model.evaluate(test_data, test_target, steps=2500)
print(scores)
# Out:
# 2500/2500 [==============================] - 7s 3ms/step - loss: 2.6855 - mse: 2.6855 - mae: 1.2284 - mape: 20.1972
# [2.6854591369628906, 2.685459613800049, 1.2284021377563477, 20.19718360900879]

# %%
#model.save(path+"IMDB_ADLFM_baseline")
# Out:
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/캡스톤/data/IMDB_ADLFM_baseline/assets
