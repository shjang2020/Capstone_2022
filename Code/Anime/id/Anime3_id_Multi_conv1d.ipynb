# %%
import tensorflow as tf
import random
import os
import pickle
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
def seed_everything(seed: int = 42):
    random.seed(seed)
    np.random.seed(seed)
    os.environ["PYTHONHASHSEED"] = str(seed)
    tf.random.set_seed(seed)

seed_everything(42)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = '/content/drive/MyDrive/Colab Notebooks/캡스톤/data/Anime3/'

# %%
with open(path+"train_id_data.pickle","rb") as fr:
    train_data = pickle.load(fr)
    
with open(path+"valid_id_data.pickle","rb") as fr:
    valid_data = pickle.load(fr)
    
with open(path+"test_id_data.pickle","rb") as fr:
    test_data = pickle.load(fr)

# %%
with open(path+"train_target.pickle","rb") as fr:
    train_target = pickle.load(fr)
    
with open(path+"valid_target.pickle","rb") as fr:
    valid_target = pickle.load(fr)
    
with open(path+"test_target.pickle","rb") as fr:
    test_target = pickle.load(fr)

# %%
# ID
train_data[0] = tf.convert_to_tensor(train_data[0], dtype=tf.float32)
train_data[1] = tf.convert_to_tensor(train_data[1], dtype=tf.float32)

# %% [markdown]
# ## Model

# %%
from tensorflow import keras
from keras.layers import Input, Embedding, LSTM, Dense, Lambda, Multiply, Bidirectional, Flatten, BatchNormalization, Add, Multiply
from keras.layers.convolutional import Conv1D
from keras.layers.pooling import MaxPool1D
from keras.models import Model
from keras.layers.wrappers import TimeDistributed
import numpy as np
import keras.backend as K
from random import randint

import os
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
description_num = 3
#current_path ='data/'
#local_path = 'data/'

# %%
# set parameters:
# V = 142381
# V = 226928
V = 48456 #  33531 6158 48456
embedding_dim = 50
max_len = 1 #  1945 77 1
filters_num = 64
kernel_size_1 = 3
kernel_size_2 = 5
kernel_size_3 = 7

# %%
# description_input=Input(shape=(10,50))
# description_validation=Input(shape=(50,))
input_1 = Input(shape=(description_num, max_len))
input_2 = Input(shape=(max_len,))
embedding = Embedding(input_dim=V,
                      output_dim=embedding_dim,
                      input_length=max_len)
conv1d_1 = Conv1D(filters=filters_num,
                kernel_size=kernel_size_1,
                activation='relu',
                padding='same')
conv1d_2 = Conv1D(filters=filters_num,
                kernel_size=kernel_size_2,
                activation='relu',
                padding='same')
conv1d_3 = Conv1D(filters=filters_num,
                kernel_size=kernel_size_3,
                activation='relu',
                padding='same')
maxpool1d = MaxPool1D(max_len)
dense = Dense(15)

# input_vector=TimeDistributed(embedding)(description_input)
# validation_vector=embedding(description_validation)

input_vector = TimeDistributed(embedding)(input_1)
validation_vector = embedding(input_2)

convolutional_vector_1 = TimeDistributed(conv1d_1)(input_vector)
validation_conv_1 = conv1d_1(validation_vector)

convolutional_vector_2 = TimeDistributed(conv1d_2)(input_vector)
validation_conv_2 = conv1d_2(validation_vector)

convolutional_vector_3 = TimeDistributed(conv1d_3)(input_vector)
validation_conv_3 = conv1d_3(validation_vector)

convolutional_merge = Multiply()([convolutional_vector_1, convolutional_vector_2, convolutional_vector_3])
validation_merge = Multiply()([validation_conv_1, validation_conv_2, validation_conv_3])

maxpooling_vector = TimeDistributed(maxpool1d)(convolutional_merge)
validation_maxpooling = maxpool1d(validation_merge)

middle_output = TimeDistributed(dense)(maxpooling_vector)
middle_validation = dense(validation_maxpooling)

# %%
print(input_vector.shape, validation_vector.shape,
      convolutional_vector_1.shape, validation_conv_1.shape,
      maxpooling_vector.shape, validation_maxpooling.shape,
      middle_output.shape, middle_validation.shape)
# Out:
# (None, 3, 1, 50) (None, 1, 50) (None, 3, 1, 64) (None, 1, 64) (None, 3, 1, 64) (None, 1, 64) (None, 3, 1, 15) (None, 1, 15)

# %%
def change_dim_1(X):
    return K.squeeze(X, 1)

def change_dim_2(X):
    return K.squeeze(X, 2)

def repeat(X):
    return K.repeat_elements(X, description_num, 1)

def repeat1(X):
    return K.repeat_elements(X, 15, 2)

def repeat2(X):
    return K.repeat_elements(X, description_num, 1)

def dot(X, Y):
    return K.dot(X, Y)

def sum_item(X):
    return K.sum(X, axis=2)

def sqrt_item(X):
    return K.sqrt(X)

def cal_denominator(X):
    return 1/(X)

def expand_item(X):
    return K.expand_dims(X, 2)

def expand_rate(X):
    return K.expand_dims(X, 1)

def sum_user(X):
    return K.sum(X, 1)

def sum_rate(X):
    return K.sum(X, 1)

def single_exp(X):
    return K.exp(X)

def sum_exp_denominator(X):
    return 1/(K.sum(K.exp(X), 1))

# %%
# def _test_generator(filename):

middle_output_final = Lambda(change_dim_2)(middle_output)#?*10*15
middle_validation_final = Lambda(repeat)(middle_validation)#?*10*15
molecule = Multiply()([middle_output_final, middle_validation_final])
molecule = Lambda(sum_item)(molecule)

denominator1 = Multiply()([middle_output_final, middle_output_final])
denominator1 = Lambda(sum_item)(denominator1)
denominator1 = Lambda(sqrt_item)(denominator1)

denominator2 = Multiply()([middle_validation_final, middle_validation_final])
denominator2 = Lambda(sum_item)(denominator2)
denominator2 = Lambda(sqrt_item)(denominator2)


denominator = Multiply()([denominator1, denominator2])
denominator = Lambda(cal_denominator)(denominator)

similarity = Multiply()([molecule, denominator])
similarity = Lambda(expand_item)(similarity)
similarity = Lambda(repeat1)(similarity)


user = Multiply()([similarity, middle_output_final])
user = Lambda(sum_user)(user)


item = Lambda(change_dim_1)(middle_validation)


rate_hat = Multiply()([user, item])
rate_hat = Lambda(sum_rate)(rate_hat)
rate_hat = Lambda(expand_rate)(rate_hat)

# %%
model = Model(inputs=[input_1, input_2], outputs=rate_hat)
model.compile(optimizer='adam', loss='mse', metrics=['mse', 'mae', 'mape'])

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 3, 1)]       0           []
#
#  input_2 (InputLayer)           [(None, 1)]          0           []
#
#  time_distributed (TimeDistribu  (None, 3, 1, 50)    2422800     ['input_1[0][0]']
#  ted)
#
#  embedding (Embedding)          (None, 1, 50)        2422800     ['input_2[0][0]']
#
#  time_distributed_1 (TimeDistri  (None, 3, 1, 64)    9664        ['time_distributed[0][0]']
#  buted)
#
#  time_distributed_2 (TimeDistri  (None, 3, 1, 64)    16064       ['time_distributed[0][0]']
#  buted)
#
#  time_distributed_3 (TimeDistri  (None, 3, 1, 64)    22464       ['time_distributed[0][0]']
#  buted)
#
#  conv1d (Conv1D)                (None, 1, 64)        9664        ['embedding[0][0]']
#
#  conv1d_1 (Conv1D)              (None, 1, 64)        16064       ['embedding[0][0]']
#
#  conv1d_2 (Conv1D)              (None, 1, 64)        22464       ['embedding[0][0]']
#
#  multiply (Multiply)            (None, 3, 1, 64)     0           ['time_distributed_1[0][0]',
#                                                                   'time_distributed_2[0][0]',
#                                                                   'time_distributed_3[0][0]']
#
#  multiply_1 (Multiply)          (None, 1, 64)        0           ['conv1d[0][0]',
#                                                                   'conv1d_1[0][0]',
#                                                                   'conv1d_2[0][0]']
#
#  time_distributed_4 (TimeDistri  (None, 3, 1, 64)    0           ['multiply[0][0]']
#  buted)
#
#  max_pooling1d (MaxPooling1D)   (None, 1, 64)        0           ['multiply_1[0][0]']
#
#  time_distributed_5 (TimeDistri  (None, 3, 1, 15)    975         ['time_distributed_4[0][0]']
#  buted)
#
#  dense (Dense)                  (None, 1, 15)        975         ['max_pooling1d[0][0]']
#
#  lambda (Lambda)                (None, 3, 15)        0           ['time_distributed_5[0][0]']
#
#  lambda_1 (Lambda)              (None, 3, 15)        0           ['dense[0][0]']
#
#  multiply_3 (Multiply)          (None, 3, 15)        0           ['lambda[0][0]',
#                                                                   'lambda[0][0]']
#
#  multiply_4 (Multiply)          (None, 3, 15)        0           ['lambda_1[0][0]',
#                                                                   'lambda_1[0][0]']
#
#  lambda_3 (Lambda)              (None, 3)            0           ['multiply_3[0][0]']
#
#  lambda_5 (Lambda)              (None, 3)            0           ['multiply_4[0][0]']
#
#  lambda_4 (Lambda)              (None, 3)            0           ['lambda_3[0][0]']
#
#  lambda_6 (Lambda)              (None, 3)            0           ['lambda_5[0][0]']
#
#  multiply_2 (Multiply)          (None, 3, 15)        0           ['lambda[0][0]',
#                                                                   'lambda_1[0][0]']
#
#  multiply_5 (Multiply)          (None, 3)            0           ['lambda_4[0][0]',
#                                                                   'lambda_6[0][0]']
#
#  lambda_2 (Lambda)              (None, 3)            0           ['multiply_2[0][0]']
#
#  lambda_7 (Lambda)              (None, 3)            0           ['multiply_5[0][0]']
#
#  multiply_6 (Multiply)          (None, 3)            0           ['lambda_2[0][0]',
#                                                                   'lambda_7[0][0]']
#
#  lambda_8 (Lambda)              (None, 3, 1)         0           ['multiply_6[0][0]']
#
#  lambda_9 (Lambda)              (None, 3, 15)        0           ['lambda_8[0][0]']
#
#  multiply_7 (Multiply)          (None, 3, 15)        0           ['lambda_9[0][0]',
#                                                                   'lambda[0][0]']
#
#  lambda_10 (Lambda)             (None, 15)           0           ['multiply_7[0][0]']
#
#  lambda_11 (Lambda)             (None, 15)           0           ['dense[0][0]']
#
#  multiply_8 (Multiply)          (None, 15)           0           ['lambda_10[0][0]',
#                                                                   'lambda_11[0][0]']
#
#  lambda_12 (Lambda)             (None,)              0           ['multiply_8[0][0]']
#
#  lambda_13 (Lambda)             (None, 1)            0           ['lambda_12[0][0]']
#
# ==================================================================================================
# Total params: 2,471,967
# Trainable params: 2,471,967
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
hist = model.fit(train_data, train_target,
                 validation_data=(valid_data, valid_target),
                 steps_per_epoch=256,
                 validation_steps=256,
                 epochs=30,
                 verbose=1)
# Out:
# Epoch 1/30
# 256/256 [==============================] - 16s 13ms/step - loss: 28.2049 - mse: 28.2049 - mae: 3.9987 - mape: 48.9482 - val_loss: 3.7711 - val_mse: 3.7711 - val_mae: 1.4019 - val_mape: 22.2238
# Epoch 2/30
# 256/256 [==============================] - 3s 10ms/step - loss: 2.5426 - mse: 2.5426 - mae: 1.1949 - mape: 19.0257 - val_loss: 2.7799 - val_mse: 2.7799 - val_mae: 1.2082 - val_mape: 20.8054
# Epoch 3/30
# 256/256 [==============================] - 3s 10ms/step - loss: 2.0699 - mse: 2.0699 - mae: 1.0935 - mape: 17.9245 - val_loss: 2.6419 - val_mse: 2.6419 - val_mae: 1.2027 - val_mape: 20.3731
# Epoch 4/30
# 256/256 [==============================] - 3s 10ms/step - loss: 1.9999 - mse: 1.9999 - mae: 1.0742 - mape: 17.5393 - val_loss: 2.6465 - val_mse: 2.6465 - val_mae: 1.1962 - val_mape: 20.3696
# Epoch 5/30
# 256/256 [==============================] - 3s 10ms/step - loss: 1.9740 - mse: 1.9740 - mae: 1.0652 - mape: 17.3877 - val_loss: 2.6547 - val_mse: 2.6547 - val_mae: 1.1864 - val_mape: 20.4930
# Epoch 6/30
# 256/256 [==============================] - 3s 10ms/step - loss: 1.9674 - mse: 1.9674 - mae: 1.0626 - mape: 17.3335 - val_loss: 2.6975 - val_mse: 2.6975 - val_mae: 1.1842 - val_mape: 20.6895
# Epoch 7/30
# 256/256 [==============================] - 3s 10ms/step - loss: 1.9633 - mse: 1.9633 - mae: 1.0613 - mape: 17.3037 - val_loss: 2.5974 - val_mse: 2.5974 - val_mae: 1.2068 - val_mape: 20.2803
# Epoch 8/30
# 256/256 [==============================] - 3s 10ms/step - loss: 1.9569 - mse: 1.9569 - mae: 1.0589 - mape: 17.2433 - val_loss: 2.5704 - val_mse: 2.5704 - val_mae: 1.1961 - val_mape: 20.2368
# Epoch 9/30
# 256/256 [==============================] - 3s 10ms/step - loss: 1.9554 - mse: 1.9554 - mae: 1.0586 - mape: 17.2537 - val_loss: 2.5657 - val_mse: 2.5657 - val_mae: 1.1879 - val_mape: 20.2592
# Epoch 10/30
# 256/256 [==============================] - 3s 11ms/step - loss: 1.9497 - mse: 1.9497 - mae: 1.0565 - mape: 17.2274 - val_loss: 2.5642 - val_mse: 2.5642 - val_mae: 1.1800 - val_mape: 20.2864
# Epoch 11/30
# 256/256 [==============================] - 3s 10ms/step - loss: 1.9526 - mse: 1.9526 - mae: 1.0568 - mape: 17.2195 - val_loss: 2.5420 - val_mse: 2.5420 - val_mae: 1.1854 - val_mape: 20.2441
# Epoch 12/30
# 256/256 [==============================] - 3s 10ms/step - loss: 1.9494 - mse: 1.9494 - mae: 1.0577 - mape: 17.2243 - val_loss: 2.5506 - val_mse: 2.5506 - val_mae: 1.1769 - val_mape: 20.2989
# Epoch 13/30
# 256/256 [==============================] - 3s 10ms/step - loss: 1.9392 - mse: 1.9392 - mae: 1.0533 - mape: 17.1766 - val_loss: 2.5186 - val_mse: 2.5186 - val_mae: 1.2001 - val_mape: 20.1821
# Epoch 14/30
# 256/256 [==============================] - 3s 10ms/step - loss: 1.9404 - mse: 1.9404 - mae: 1.0545 - mape: 17.1752 - val_loss: 2.5287 - val_mse: 2.5287 - val_mae: 1.1747 - val_mape: 20.2696
# Epoch 15/30
# 256/256 [==============================] - 3s 10ms/step - loss: 1.9442 - mse: 1.9442 - mae: 1.0557 - mape: 17.2029 - val_loss: 2.5055 - val_mse: 2.5055 - val_mae: 1.1970 - val_mape: 20.1811
# Epoch 16/30
# 256/256 [==============================] - 3s 10ms/step - loss: 1.9332 - mse: 1.9332 - mae: 1.0520 - mape: 17.1481 - val_loss: 2.4826 - val_mse: 2.4826 - val_mae: 1.1902 - val_mape: 20.1593
# Epoch 17/30
# 256/256 [==============================] - 3s 10ms/step - loss: 1.9286 - mse: 1.9286 - mae: 1.0500 - mape: 17.1267 - val_loss: 2.4950 - val_mse: 2.4950 - val_mae: 1.1740 - val_mape: 20.2047
# Epoch 18/30
# 256/256 [==============================] - 3s 10ms/step - loss: 1.9276 - mse: 1.9276 - mae: 1.0507 - mape: 17.1178 - val_loss: 2.4840 - val_mse: 2.4840 - val_mae: 1.1820 - val_mape: 20.1631
# Epoch 19/30
# 256/256 [==============================] - 3s 10ms/step - loss: 1.9255 - mse: 1.9255 - mae: 1.0491 - mape: 17.1146 - val_loss: 2.4862 - val_mse: 2.4862 - val_mae: 1.1772 - val_mape: 20.1781
# Epoch 20/30
# 256/256 [==============================] - 3s 10ms/step - loss: 1.9273 - mse: 1.9273 - mae: 1.0502 - mape: 17.1160 - val_loss: 2.4800 - val_mse: 2.4800 - val_mae: 1.1818 - val_mape: 20.1493
# Epoch 21/30
# 256/256 [==============================] - 3s 10ms/step - loss: 1.9258 - mse: 1.9258 - mae: 1.0504 - mape: 17.1187 - val_loss: 2.4924 - val_mse: 2.4924 - val_mae: 1.1729 - val_mape: 20.2028
# Epoch 22/30
# 256/256 [==============================] - 3s 10ms/step - loss: 1.9219 - mse: 1.9219 - mae: 1.0485 - mape: 17.0875 - val_loss: 2.4673 - val_mse: 2.4673 - val_mae: 1.1818 - val_mape: 20.1224
# Epoch 23/30
# 256/256 [==============================] - 3s 10ms/step - loss: 1.9234 - mse: 1.9234 - mae: 1.0490 - mape: 17.0944 - val_loss: 2.4654 - val_mse: 2.4654 - val_mae: 1.1965 - val_mape: 20.1303
# Epoch 24/30
# 256/256 [==============================] - 3s 10ms/step - loss: 1.9206 - mse: 1.9206 - mae: 1.0492 - mape: 17.0823 - val_loss: 2.4468 - val_mse: 2.4468 - val_mae: 1.1749 - val_mape: 20.1247
# Epoch 25/30
# 256/256 [==============================] - 3s 10ms/step - loss: 1.9187 - mse: 1.9187 - mae: 1.0475 - mape: 17.0869 - val_loss: 2.4613 - val_mse: 2.4613 - val_mae: 1.1710 - val_mape: 20.1535
# Epoch 26/30
# 256/256 [==============================] - 3s 10ms/step - loss: 1.9164 - mse: 1.9164 - mae: 1.0466 - mape: 17.0671 - val_loss: 2.4985 - val_mse: 2.4985 - val_mae: 1.1592 - val_mape: 20.2942
# Epoch 27/30
# 256/256 [==============================] - 3s 10ms/step - loss: 1.9138 - mse: 1.9138 - mae: 1.0456 - mape: 17.0479 - val_loss: 2.4425 - val_mse: 2.4425 - val_mae: 1.1814 - val_mape: 20.1059
# Epoch 28/30
# 256/256 [==============================] - 3s 10ms/step - loss: 1.9149 - mse: 1.9149 - mae: 1.0463 - mape: 17.0621 - val_loss: 2.4631 - val_mse: 2.4631 - val_mae: 1.1645 - val_mape: 20.1637
# Epoch 29/30
# 256/256 [==============================] - 3s 10ms/step - loss: 1.9184 - mse: 1.9184 - mae: 1.0475 - mape: 17.0673 - val_loss: 2.4519 - val_mse: 2.4519 - val_mae: 1.1714 - val_mape: 20.1521
# Epoch 30/30
# 256/256 [==============================] - 3s 10ms/step - loss: 1.9137 - mse: 1.9137 - mae: 1.0458 - mape: 17.0411 - val_loss: 2.4220 - val_mse: 2.4220 - val_mae: 1.1700 - val_mape: 20.1511

# %%
# scores = model.evaluate_generator(_evaluate_generator('train_whole_list_5s.txt','test_whole_list_5s.txt'),steps=134103)
# scores = model.evaluate_generator(_evaluate_generator('train_whole_list_10.txt','test_whole_list_10.txt'),steps=34266)
# scores = model.evaluate_generator(_evaluate_generator('train_whole_list_6s.txt','test_whole_list_6s.txt'),steps=134103)
scores = model.evaluate(test_data, test_target, steps=2500)
print(scores)
# Out:
# 2500/2500 [==============================] - 8s 3ms/step - loss: 2.3098 - mse: 2.3098 - mae: 1.1527 - mape: 19.0310
# [2.309847831726074, 2.309847831726074, 1.1526983976364136, 19.031028747558594]

# %%
# model.save('/content/drive/MyDrive/Colab Notebooks/캡스톤/IMDB_ADLFM_Multi_conv1d')
# Out:
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/캡스톤/IMDB_ADLFM_Multi_conv1d/assets
