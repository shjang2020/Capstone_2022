# %%
import tensorflow as tf
import random
import os
import pickle
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
def seed_everything(seed: int = 42):
    random.seed(seed)
    np.random.seed(seed)
    os.environ["PYTHONHASHSEED"] = str(seed)
    tf.random.set_seed(seed)

seed_everything(42)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = '/content/drive/MyDrive/Colab Notebooks/캡스톤/data3/'

# %%
with open(path+"train_id_data.pickle","rb") as fr:
    train_data = pickle.load(fr)
    
with open(path+"valid_id_data.pickle","rb") as fr:
    valid_data = pickle.load(fr)
    
with open(path+"test_id_data.pickle","rb") as fr:
    test_data = pickle.load(fr)

# %%
with open(path+"train_target.pickle","rb") as fr:
    train_target = pickle.load(fr)
    
with open(path+"valid_target.pickle","rb") as fr:
    valid_target = pickle.load(fr)
    
with open(path+"test_target.pickle","rb") as fr:
    test_target = pickle.load(fr)

# %%
# ID
train_data[0] = tf.convert_to_tensor(train_data[0], dtype=tf.float32)
train_data[1] = tf.convert_to_tensor(train_data[1], dtype=tf.float32)

# %% [markdown]
# ## Model

# %%
# !pip install keras_multi_head
#!pip install keras_self_attention
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting keras_multi_head
#   Downloading keras-multi-head-0.29.0.tar.gz (13 kB)
# Collecting keras-self-attention==0.51.0
#   Downloading keras-self-attention-0.51.0.tar.gz (11 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from keras-self-attention==0.51.0->keras_multi_head) (1.21.6)
# Building wheels for collected packages: keras-multi-head, keras-self-attention
#   Building wheel for keras-multi-head (setup.py) ... done
#   Created wheel for keras-multi-head: filename=keras_multi_head-0.29.0-py3-none-any.whl size=14993 sha256=0438e2e36b8575604662b9bcc3cc6c9d84100d58c449cc27bc6aa65a2aa7701a
#   Stored in directory: /root/.cache/pip/wheels/86/aa/3c/9d15d24005179dae08ff291ce99c754b296347817d076fd9fb
#   Building wheel for keras-self-attention (setup.py) ... done
#   Created wheel for keras-self-attention: filename=keras_self_attention-0.51.0-py3-none-any.whl size=18912 sha256=caae1e0df54920086cbd81310330608ef2c25b5190d3af09bae34ada792c78b9
#   Stored in directory: /root/.cache/pip/wheels/95/b1/a8/5ee00cc137940b2f6fa198212e8f45d813d0e0d9c3a04035a3
# Successfully built keras-multi-head keras-self-attention
# Installing collected packages: keras-self-attention, keras-multi-head
# Successfully installed keras-multi-head-0.29.0 keras-self-attention-0.51.0

# %%
from tensorflow import keras
from keras.layers import Input, Embedding, LSTM, Dense, Lambda, Multiply, Bidirectional, Flatten, BatchNormalization, Add
from keras.layers.convolutional import Conv1D
from keras.layers.pooling import MaxPool1D
from keras.models import Model
from keras.layers.wrappers import TimeDistributed
import numpy as np
import keras.backend as K
from random import randint
from keras_multi_head import MultiHead
#from keras_self_attention import SeqSelfAttention as Attention

import os
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
description_num = 3
#current_path ='data/'
#local_path = 'data/'

# %%
# set parameters:
# V = 142381
# V = 226928
V = 48456 # 48456 #  33531 6158 48456
embedding_dim = 50
max_len = 1 # 1 #  1945 77 1
filters_num = 64
kernel_size = 3

# %%
# description_input=Input(shape=(10,50))
# description_validation=Input(shape=(50,))
input_1 = Input(shape=(description_num, max_len))
input_2 = Input(shape=(max_len,))
embedding = Embedding(input_dim=V,
                      output_dim=embedding_dim,
                      input_length=max_len)
conv1d = Conv1D(filters=filters_num,
                kernel_size=kernel_size,
                activation='relu',
                padding='same')
maxpool1d = MaxPool1D(max_len)
batchnorm1d = BatchNormalization()
dense = Dense(15)

# input_vector=TimeDistributed(embedding)(description_input)
# validation_vector=embedding(description_validation)

input_vector = TimeDistributed(embedding)(input_1)
validation_vector = embedding(input_2)

convolutional_vector = TimeDistributed(MultiHead(conv1d))(input_vector)
validation_conv = MultiHead(conv1d)(validation_vector)
convolutional_vector = tf.keras.backend.squeeze(convolutional_vector, axis=4)
validation_conv = tf.keras.backend.squeeze(validation_conv, axis=3)

maxpooling_vector = TimeDistributed(maxpool1d)(convolutional_vector)
validation_maxpooling = maxpool1d(validation_conv)

middle_output = TimeDistributed(dense)(maxpooling_vector)
middle_validation = dense(validation_maxpooling)

# %%
print(input_vector.shape, validation_vector.shape,
      convolutional_vector.shape, validation_conv.shape,
      maxpooling_vector.shape, validation_maxpooling.shape,
      middle_output.shape, middle_validation.shape)
# Out:
# (None, 3, 1, 50) (None, 1, 50) (None, 3, 1, 64) (None, 1, 64) (None, 3, 1, 64) (None, 1, 64) (None, 3, 1, 15) (None, 1, 15)

# %%
def change_dim_1(X):
    return K.squeeze(X, 1)

def change_dim_2(X):
    return K.squeeze(X, 2)

def repeat(X):
    return K.repeat_elements(X, description_num, 1)

def repeat1(X):
    return K.repeat_elements(X, 15, 2)

def repeat2(X):
    return K.repeat_elements(X, description_num, 1)

def dot(X, Y):
    return K.dot(X, Y)

def sum_item(X):
    return K.sum(X, axis=2)

def sqrt_item(X):
    return K.sqrt(X)

def cal_denominator(X):
    return 1/(X)

def expand_item(X):
    return K.expand_dims(X, 2)

def expand_rate(X):
    return K.expand_dims(X, 1)

def sum_user(X):
    return K.sum(X, 1)

def sum_rate(X):
    return K.sum(X, 1)

def single_exp(X):
    return K.exp(X)

def sum_exp_denominator(X):
    return 1/(K.sum(K.exp(X), 1))

# %%
# def _test_generator(filename):

middle_output_final = Lambda(change_dim_2)(middle_output)#?*10*15
middle_validation_final = Lambda(repeat)(middle_validation)#?*10*15
molecule = Multiply()([middle_output_final, middle_validation_final])
molecule = Lambda(sum_item)(molecule)

denominator1 = Multiply()([middle_output_final, middle_output_final])
denominator1 = Lambda(sum_item)(denominator1)
denominator1 = Lambda(sqrt_item)(denominator1)

denominator2 = Multiply()([middle_validation_final, middle_validation_final])
denominator2 = Lambda(sum_item)(denominator2)
denominator2 = Lambda(sqrt_item)(denominator2)


denominator = Multiply()([denominator1, denominator2])
denominator = Lambda(cal_denominator)(denominator)

similarity = Multiply()([molecule, denominator])
similarity = Lambda(expand_item)(similarity)
similarity = Lambda(repeat1)(similarity)


user = Multiply()([similarity, middle_output_final])
user = Lambda(sum_user)(user)


item = Lambda(change_dim_1)(middle_validation)


rate_hat = Multiply()([user, item])
rate_hat = Lambda(sum_rate)(rate_hat)
rate_hat = Lambda(expand_rate)(rate_hat)

# %%
model = Model(inputs=[input_1, input_2], outputs=rate_hat)
model.compile(optimizer='adam', loss='mse', metrics=['mse', 'mae', 'mape'])

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 3, 1)]       0           []
#
#  input_2 (InputLayer)           [(None, 1)]          0           []
#
#  time_distributed (TimeDistribu  (None, 3, 1, 50)    2422800     ['input_1[0][0]']
#  ted)
#
#  embedding (Embedding)          (None, 1, 50)        2422800     ['input_2[0][0]']
#
#  time_distributed_1 (TimeDistri  (None, 3, 1, 64, 1)  9664       ['time_distributed[0][0]']
#  buted)
#
#  multi_head_1 (MultiHead)       (None, 1, 64, 1)     9664        ['embedding[0][0]']
#
#  tf.compat.v1.squeeze (TFOpLamb  (None, 3, 1, 64)    0           ['time_distributed_1[0][0]']
#  da)
#
#  tf.compat.v1.squeeze_1 (TFOpLa  (None, 1, 64)       0           ['multi_head_1[0][0]']
#  mbda)
#
#  time_distributed_2 (TimeDistri  (None, 3, 1, 64)    0           ['tf.compat.v1.squeeze[0][0]']
#  buted)
#
#  max_pooling1d (MaxPooling1D)   (None, 1, 64)        0           ['tf.compat.v1.squeeze_1[0][0]']
#
#  time_distributed_3 (TimeDistri  (None, 3, 1, 15)    975         ['time_distributed_2[0][0]']
#  buted)
#
#  dense (Dense)                  (None, 1, 15)        975         ['max_pooling1d[0][0]']
#
#  lambda (Lambda)                (None, 3, 15)        0           ['time_distributed_3[0][0]']
#
#  lambda_1 (Lambda)              (None, 3, 15)        0           ['dense[0][0]']
#
#  multiply_1 (Multiply)          (None, 3, 15)        0           ['lambda[0][0]',
#                                                                   'lambda[0][0]']
#
#  multiply_2 (Multiply)          (None, 3, 15)        0           ['lambda_1[0][0]',
#                                                                   'lambda_1[0][0]']
#
#  lambda_3 (Lambda)              (None, 3)            0           ['multiply_1[0][0]']
#
#  lambda_5 (Lambda)              (None, 3)            0           ['multiply_2[0][0]']
#
#  lambda_4 (Lambda)              (None, 3)            0           ['lambda_3[0][0]']
#
#  lambda_6 (Lambda)              (None, 3)            0           ['lambda_5[0][0]']
#
#  multiply (Multiply)            (None, 3, 15)        0           ['lambda[0][0]',
#                                                                   'lambda_1[0][0]']
#
#  multiply_3 (Multiply)          (None, 3)            0           ['lambda_4[0][0]',
#                                                                   'lambda_6[0][0]']
#
#  lambda_2 (Lambda)              (None, 3)            0           ['multiply[0][0]']
#
#  lambda_7 (Lambda)              (None, 3)            0           ['multiply_3[0][0]']
#
#  multiply_4 (Multiply)          (None, 3)            0           ['lambda_2[0][0]',
#                                                                   'lambda_7[0][0]']
#
#  lambda_8 (Lambda)              (None, 3, 1)         0           ['multiply_4[0][0]']
#
#  lambda_9 (Lambda)              (None, 3, 15)        0           ['lambda_8[0][0]']
#
#  multiply_5 (Multiply)          (None, 3, 15)        0           ['lambda_9[0][0]',
#                                                                   'lambda[0][0]']
#
#  lambda_10 (Lambda)             (None, 15)           0           ['multiply_5[0][0]']
#
#  lambda_11 (Lambda)             (None, 15)           0           ['dense[0][0]']
#
#  multiply_6 (Multiply)          (None, 15)           0           ['lambda_10[0][0]',
#                                                                   'lambda_11[0][0]']
#
#  lambda_12 (Lambda)             (None,)              0           ['multiply_6[0][0]']
#
#  lambda_13 (Lambda)             (None, 1)            0           ['lambda_12[0][0]']
#
# ==================================================================================================
# Total params: 2,443,103
# Trainable params: 2,443,103
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
hist = model.fit(train_data, train_target,
                 validation_data=(valid_data, valid_target),
                 steps_per_epoch=256,
                 validation_steps=256,
                 epochs=30,
                 verbose=1)
# Out:
# Epoch 1/30
# 256/256 [==============================] - 23s 25ms/step - loss: 12.8202 - mse: 12.8202 - mae: 2.3465 - mape: 31.3220 - val_loss: 2.5903 - val_mse: 2.5903 - val_mae: 1.2111 - val_mape: 20.4943
# Epoch 2/30
# 256/256 [==============================] - 6s 23ms/step - loss: 2.1126 - mse: 2.1126 - mae: 1.1030 - mape: 18.1203 - val_loss: 2.4468 - val_mse: 2.4468 - val_mae: 1.1802 - val_mape: 20.1944
# Epoch 3/30
# 256/256 [==============================] - 6s 23ms/step - loss: 1.9874 - mse: 1.9874 - mae: 1.0664 - mape: 17.5693 - val_loss: 2.4443 - val_mse: 2.4443 - val_mae: 1.1526 - val_mape: 20.0509
# Epoch 4/30
# 256/256 [==============================] - 6s 23ms/step - loss: 1.9187 - mse: 1.9187 - mae: 1.0449 - mape: 17.1116 - val_loss: 2.4326 - val_mse: 2.4326 - val_mae: 1.1517 - val_mape: 20.0491
# Epoch 5/30
# 256/256 [==============================] - 6s 23ms/step - loss: 1.8783 - mse: 1.8783 - mae: 1.0313 - mape: 16.8403 - val_loss: 2.4141 - val_mse: 2.4141 - val_mae: 1.1436 - val_mape: 20.1269
# Epoch 6/30
# 256/256 [==============================] - 6s 22ms/step - loss: 1.8545 - mse: 1.8545 - mae: 1.0234 - mape: 16.6869 - val_loss: 2.4381 - val_mse: 2.4381 - val_mae: 1.1435 - val_mape: 20.2058
# Epoch 7/30
# 256/256 [==============================] - 6s 22ms/step - loss: 1.8411 - mse: 1.8411 - mae: 1.0186 - mape: 16.5930 - val_loss: 2.4071 - val_mse: 2.4071 - val_mae: 1.1582 - val_mape: 19.9991
# Epoch 8/30
# 256/256 [==============================] - 6s 23ms/step - loss: 1.8295 - mse: 1.8295 - mae: 1.0150 - mape: 16.4855 - val_loss: 2.3918 - val_mse: 2.3918 - val_mae: 1.1585 - val_mape: 20.0554
# Epoch 9/30
# 256/256 [==============================] - 6s 23ms/step - loss: 1.8183 - mse: 1.8183 - mae: 1.0111 - mape: 16.4303 - val_loss: 2.4160 - val_mse: 2.4160 - val_mae: 1.1541 - val_mape: 20.1156
# Epoch 10/30
# 256/256 [==============================] - 6s 23ms/step - loss: 1.8122 - mse: 1.8122 - mae: 1.0097 - mape: 16.3824 - val_loss: 2.4213 - val_mse: 2.4213 - val_mae: 1.1591 - val_mape: 20.0958
# Epoch 11/30
# 256/256 [==============================] - 6s 23ms/step - loss: 1.8154 - mse: 1.8154 - mae: 1.0102 - mape: 16.3854 - val_loss: 2.4281 - val_mse: 2.4281 - val_mae: 1.1612 - val_mape: 20.0391
# Epoch 12/30
# 256/256 [==============================] - 6s 25ms/step - loss: 1.8038 - mse: 1.8038 - mae: 1.0081 - mape: 16.3253 - val_loss: 2.4508 - val_mse: 2.4508 - val_mae: 1.1522 - val_mape: 20.2812
# Epoch 13/30
# 256/256 [==============================] - 6s 23ms/step - loss: 1.7937 - mse: 1.7937 - mae: 1.0038 - mape: 16.2631 - val_loss: 2.4022 - val_mse: 2.4022 - val_mae: 1.1730 - val_mape: 19.9774
# Epoch 14/30
# 256/256 [==============================] - 6s 23ms/step - loss: 1.7818 - mse: 1.7818 - mae: 1.0008 - mape: 16.2063 - val_loss: 2.4658 - val_mse: 2.4658 - val_mae: 1.1670 - val_mape: 20.1795
# Epoch 15/30
# 256/256 [==============================] - 6s 23ms/step - loss: 1.7668 - mse: 1.7668 - mae: 0.9962 - mape: 16.1065 - val_loss: 2.4213 - val_mse: 2.4213 - val_mae: 1.1684 - val_mape: 20.0687
# Epoch 16/30
# 256/256 [==============================] - 6s 22ms/step - loss: 1.7410 - mse: 1.7410 - mae: 0.9886 - mape: 15.9515 - val_loss: 2.4443 - val_mse: 2.4443 - val_mae: 1.1800 - val_mape: 20.0904
# Epoch 17/30
# 256/256 [==============================] - 6s 22ms/step - loss: 1.7086 - mse: 1.7086 - mae: 0.9778 - mape: 15.7394 - val_loss: 2.4329 - val_mse: 2.4329 - val_mae: 1.1724 - val_mape: 20.1025
# Epoch 18/30
# 256/256 [==============================] - 6s 23ms/step - loss: 1.6786 - mse: 1.6786 - mae: 0.9689 - mape: 15.5281 - val_loss: 2.4673 - val_mse: 2.4673 - val_mae: 1.1637 - val_mape: 20.2195
# Epoch 19/30
# 256/256 [==============================] - 6s 23ms/step - loss: 1.6474 - mse: 1.6474 - mae: 0.9583 - mape: 15.3522 - val_loss: 2.5013 - val_mse: 2.5013 - val_mae: 1.1938 - val_mape: 20.2258
# Epoch 20/30
# 256/256 [==============================] - 6s 22ms/step - loss: 1.6132 - mse: 1.6132 - mae: 0.9485 - mape: 15.1260 - val_loss: 2.5325 - val_mse: 2.5325 - val_mae: 1.1703 - val_mape: 20.3680
# Epoch 21/30
# 256/256 [==============================] - 6s 22ms/step - loss: 1.5817 - mse: 1.5817 - mae: 0.9372 - mape: 14.9050 - val_loss: 2.5553 - val_mse: 2.5553 - val_mae: 1.1832 - val_mape: 20.3297
# Epoch 22/30
# 256/256 [==============================] - 6s 23ms/step - loss: 1.5435 - mse: 1.5435 - mae: 0.9235 - mape: 14.6608 - val_loss: 2.5758 - val_mse: 2.5758 - val_mae: 1.1846 - val_mape: 20.3346
# Epoch 23/30
# 256/256 [==============================] - 6s 23ms/step - loss: 1.5115 - mse: 1.5115 - mae: 0.9129 - mape: 14.4636 - val_loss: 2.5737 - val_mse: 2.5737 - val_mae: 1.1950 - val_mape: 20.3824
# Epoch 24/30
# 256/256 [==============================] - 6s 23ms/step - loss: 1.4804 - mse: 1.4804 - mae: 0.9012 - mape: 14.2547 - val_loss: 2.5694 - val_mse: 2.5694 - val_mae: 1.1990 - val_mape: 20.3871
# Epoch 25/30
# 256/256 [==============================] - 6s 23ms/step - loss: 1.4593 - mse: 1.4593 - mae: 0.8944 - mape: 14.1178 - val_loss: 2.6731 - val_mse: 2.6731 - val_mae: 1.1909 - val_mape: 20.5967
# Epoch 26/30
# 256/256 [==============================] - 6s 23ms/step - loss: 1.4230 - mse: 1.4230 - mae: 0.8812 - mape: 13.8951 - val_loss: 2.6632 - val_mse: 2.6632 - val_mae: 1.2056 - val_mape: 20.5587
# Epoch 27/30
# 256/256 [==============================] - 6s 23ms/step - loss: 1.3992 - mse: 1.3992 - mae: 0.8712 - mape: 13.7139 - val_loss: 2.6709 - val_mse: 2.6709 - val_mae: 1.2399 - val_mape: 20.5754
# Epoch 28/30
# 256/256 [==============================] - 6s 23ms/step - loss: 1.3776 - mse: 1.3776 - mae: 0.8638 - mape: 13.5668 - val_loss: 2.7022 - val_mse: 2.7022 - val_mae: 1.2294 - val_mape: 20.6400
# Epoch 29/30
# 256/256 [==============================] - 6s 22ms/step - loss: 1.3527 - mse: 1.3527 - mae: 0.8554 - mape: 13.4009 - val_loss: 2.7584 - val_mse: 2.7584 - val_mae: 1.2123 - val_mape: 20.8637
# Epoch 30/30
# 256/256 [==============================] - 6s 23ms/step - loss: 1.3308 - mse: 1.3308 - mae: 0.8476 - mape: 13.2593 - val_loss: 2.7719 - val_mse: 2.7719 - val_mae: 1.2261 - val_mape: 20.9654

# %%
# scores = model.evaluate_generator(_evaluate_generator('train_whole_list_5s.txt','test_whole_list_5s.txt'),steps=134103)
# scores = model.evaluate_generator(_evaluate_generator('train_whole_list_10.txt','test_whole_list_10.txt'),steps=34266)
# scores = model.evaluate_generator(_evaluate_generator('train_whole_list_6s.txt','test_whole_list_6s.txt'),steps=134103)
scores = model.evaluate(test_data, test_target, steps=2500)
print(scores)
# Out:
# 2500/2500 [==============================] - 13s 5ms/step - loss: 2.7648 - mse: 2.7648 - mae: 1.2182 - mape: 20.2692
# [2.7648301124572754, 2.7648301124572754, 1.2182096242904663, 20.269235610961914]

# %%
# model.save(path+"IMDB_ADLFM_Multi_head_conv1d")
# Out:
# WARNING:absl:Found untraced functions such as conv1d_layer_call_fn, conv1d_layer_call_and_return_conditional_losses, conv1d_1_layer_call_fn, conv1d_1_layer_call_and_return_conditional_losses, conv1d_1_layer_call_fn while saving (showing 5 of 6). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/캡스톤/data/IMDB_ADLFM_Multi_head_conv1d/assets
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/캡스톤/data/IMDB_ADLFM_Multi_head_conv1d/assets
