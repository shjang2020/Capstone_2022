# %%
import tensorflow as tf
import random
import os
import pickle
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
def seed_everything(seed: int = 42):
    random.seed(seed)
    np.random.seed(seed)
    os.environ["PYTHONHASHSEED"] = str(seed)
    tf.random.set_seed(seed)

seed_everything(42)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip -qq "/content/drive/MyDrive/Colab Notebooks/캡스톤/data/beauty_3.zip"

# %%
with open("./beauty_3/train_id_data.pickle","rb") as fr:
    train_data = pickle.load(fr)
    
with open("./beauty_3/valid_id_data.pickle","rb") as fr:
    valid_data = pickle.load(fr)
    
with open("./beauty_3/test_id_data.pickle","rb") as fr:
    test_data = pickle.load(fr)

# %%
with open("./beauty_3/train_target.pickle","rb") as fr:
    train_target = pickle.load(fr)
    
with open("./beauty_3/valid_target.pickle","rb") as fr:
    valid_target = pickle.load(fr)
    
with open("./beauty_3/test_target.pickle","rb") as fr:
    test_target = pickle.load(fr)

# %%
# ID
train_data[0] = tf.convert_to_tensor(train_data[0], dtype=tf.float32)
train_data[1] = tf.convert_to_tensor(train_data[1], dtype=tf.float32)

# %% [markdown]
# ## Model

# %%
from tensorflow import keras
from keras.layers import Input, Embedding, LSTM, Dense, Lambda, Multiply, Bidirectional, Flatten, BatchNormalization, Add, Multiply
from keras.layers.convolutional import Conv1D
from keras.layers.pooling import MaxPool1D
from keras.models import Model
from keras.layers.wrappers import TimeDistributed
import numpy as np
import keras.backend as K
from random import randint

import os
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
description_num = 3
#current_path ='data/'
#local_path = 'data/'

# %%
# set parameters:
# V = 142381
# V = 226928
V = 249274 #  33531 6158 48456
embedding_dim = 50
max_len = 1 #  1945 77 1
filters_num = 64
kernel_size_1 = 3
kernel_size_2 = 5
kernel_size_3 = 7

# %%
# description_input=Input(shape=(10,50))
# description_validation=Input(shape=(50,))
input_1 = Input(shape=(description_num, max_len))
input_2 = Input(shape=(max_len,))
embedding = Embedding(input_dim=V,
                      output_dim=embedding_dim,
                      input_length=max_len)
conv1d_1 = Conv1D(filters=filters_num,
                kernel_size=kernel_size_1,
                activation='relu',
                padding='same')
conv1d_2 = Conv1D(filters=filters_num,
                kernel_size=kernel_size_2,
                activation='relu',
                padding='same')
conv1d_3 = Conv1D(filters=filters_num,
                kernel_size=kernel_size_3,
                activation='relu',
                padding='same')
maxpool1d = MaxPool1D(max_len)
dense = Dense(15)

# input_vector=TimeDistributed(embedding)(description_input)
# validation_vector=embedding(description_validation)

input_vector = TimeDistributed(embedding)(input_1)
validation_vector = embedding(input_2)

convolutional_vector_1 = TimeDistributed(conv1d_1)(input_vector)
validation_conv_1 = conv1d_1(validation_vector)

convolutional_vector_2 = TimeDistributed(conv1d_2)(input_vector)
validation_conv_2 = conv1d_2(validation_vector)

convolutional_vector_3 = TimeDistributed(conv1d_3)(input_vector)
validation_conv_3 = conv1d_3(validation_vector)

convolutional_merge = Multiply()([convolutional_vector_1, convolutional_vector_2, convolutional_vector_3])
validation_merge = Multiply()([validation_conv_1, validation_conv_2, validation_conv_3])

maxpooling_vector = TimeDistributed(maxpool1d)(convolutional_merge)
validation_maxpooling = maxpool1d(validation_merge)

middle_output = TimeDistributed(dense)(maxpooling_vector)
middle_validation = dense(validation_maxpooling)

# %%
print(input_vector.shape, validation_vector.shape,
      convolutional_vector_1.shape, validation_conv_1.shape,
      maxpooling_vector.shape, validation_maxpooling.shape,
      middle_output.shape, middle_validation.shape)
# Out:
# (None, 3, 1, 50) (None, 1, 50) (None, 3, 1, 64) (None, 1, 64) (None, 3, 1, 64) (None, 1, 64) (None, 3, 1, 15) (None, 1, 15)

# %%
def change_dim_1(X):
    return K.squeeze(X, 1)

def change_dim_2(X):
    return K.squeeze(X, 2)

def repeat(X):
    return K.repeat_elements(X, description_num, 1)

def repeat1(X):
    return K.repeat_elements(X, 15, 2)

def repeat2(X):
    return K.repeat_elements(X, description_num, 1)

def dot(X, Y):
    return K.dot(X, Y)

def sum_item(X):
    return K.sum(X, axis=2)

def sqrt_item(X):
    return K.sqrt(X)

def cal_denominator(X):
    return 1/(X)

def expand_item(X):
    return K.expand_dims(X, 2)

def expand_rate(X):
    return K.expand_dims(X, 1)

def sum_user(X):
    return K.sum(X, 1)

def sum_rate(X):
    return K.sum(X, 1)

def single_exp(X):
    return K.exp(X)

def sum_exp_denominator(X):
    return 1/(K.sum(K.exp(X), 1))

# %%
# def _test_generator(filename):

middle_output_final = Lambda(change_dim_2)(middle_output)#?*10*15
middle_validation_final = Lambda(repeat)(middle_validation)#?*10*15
molecule = Multiply()([middle_output_final, middle_validation_final])
molecule = Lambda(sum_item)(molecule)

denominator1 = Multiply()([middle_output_final, middle_output_final])
denominator1 = Lambda(sum_item)(denominator1)
denominator1 = Lambda(sqrt_item)(denominator1)

denominator2 = Multiply()([middle_validation_final, middle_validation_final])
denominator2 = Lambda(sum_item)(denominator2)
denominator2 = Lambda(sqrt_item)(denominator2)


denominator = Multiply()([denominator1, denominator2])
denominator = Lambda(cal_denominator)(denominator)

similarity = Multiply()([molecule, denominator])
similarity = Lambda(expand_item)(similarity)
similarity = Lambda(repeat1)(similarity)


user = Multiply()([similarity, middle_output_final])
user = Lambda(sum_user)(user)


item = Lambda(change_dim_1)(middle_validation)


rate_hat = Multiply()([user, item])
rate_hat = Lambda(sum_rate)(rate_hat)
rate_hat = Lambda(expand_rate)(rate_hat)

# %%
model = Model(inputs=[input_1, input_2], outputs=rate_hat)
model.compile(optimizer='adam', loss='mae', metrics=['mse', 'mae', 'mape'])

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 3, 1)]       0           []
#
#  input_2 (InputLayer)           [(None, 1)]          0           []
#
#  time_distributed (TimeDistribu  (None, 3, 1, 50)    12463700    ['input_1[0][0]']
#  ted)
#
#  embedding (Embedding)          (None, 1, 50)        12463700    ['input_2[0][0]']
#
#  time_distributed_1 (TimeDistri  (None, 3, 1, 64)    9664        ['time_distributed[0][0]']
#  buted)
#
#  time_distributed_2 (TimeDistri  (None, 3, 1, 64)    16064       ['time_distributed[0][0]']
#  buted)
#
#  time_distributed_3 (TimeDistri  (None, 3, 1, 64)    22464       ['time_distributed[0][0]']
#  buted)
#
#  conv1d (Conv1D)                (None, 1, 64)        9664        ['embedding[0][0]']
#
#  conv1d_1 (Conv1D)              (None, 1, 64)        16064       ['embedding[0][0]']
#
#  conv1d_2 (Conv1D)              (None, 1, 64)        22464       ['embedding[0][0]']
#
#  multiply (Multiply)            (None, 3, 1, 64)     0           ['time_distributed_1[0][0]',
#                                                                   'time_distributed_2[0][0]',
#                                                                   'time_distributed_3[0][0]']
#
#  multiply_1 (Multiply)          (None, 1, 64)        0           ['conv1d[0][0]',
#                                                                   'conv1d_1[0][0]',
#                                                                   'conv1d_2[0][0]']
#
#  time_distributed_4 (TimeDistri  (None, 3, 1, 64)    0           ['multiply[0][0]']
#  buted)
#
#  max_pooling1d (MaxPooling1D)   (None, 1, 64)        0           ['multiply_1[0][0]']
#
#  time_distributed_5 (TimeDistri  (None, 3, 1, 15)    975         ['time_distributed_4[0][0]']
#  buted)
#
#  dense (Dense)                  (None, 1, 15)        975         ['max_pooling1d[0][0]']
#
#  lambda (Lambda)                (None, 3, 15)        0           ['time_distributed_5[0][0]']
#
#  lambda_1 (Lambda)              (None, 3, 15)        0           ['dense[0][0]']
#
#  multiply_3 (Multiply)          (None, 3, 15)        0           ['lambda[0][0]',
#                                                                   'lambda[0][0]']
#
#  multiply_4 (Multiply)          (None, 3, 15)        0           ['lambda_1[0][0]',
#                                                                   'lambda_1[0][0]']
#
#  lambda_3 (Lambda)              (None, 3)            0           ['multiply_3[0][0]']
#
#  lambda_5 (Lambda)              (None, 3)            0           ['multiply_4[0][0]']
#
#  lambda_4 (Lambda)              (None, 3)            0           ['lambda_3[0][0]']
#
#  lambda_6 (Lambda)              (None, 3)            0           ['lambda_5[0][0]']
#
#  multiply_2 (Multiply)          (None, 3, 15)        0           ['lambda[0][0]',
#                                                                   'lambda_1[0][0]']
#
#  multiply_5 (Multiply)          (None, 3)            0           ['lambda_4[0][0]',
#                                                                   'lambda_6[0][0]']
#
#  lambda_2 (Lambda)              (None, 3)            0           ['multiply_2[0][0]']
#
#  lambda_7 (Lambda)              (None, 3)            0           ['multiply_5[0][0]']
#
#  multiply_6 (Multiply)          (None, 3)            0           ['lambda_2[0][0]',
#                                                                   'lambda_7[0][0]']
#
#  lambda_8 (Lambda)              (None, 3, 1)         0           ['multiply_6[0][0]']
#
#  lambda_9 (Lambda)              (None, 3, 15)        0           ['lambda_8[0][0]']
#
#  multiply_7 (Multiply)          (None, 3, 15)        0           ['lambda_9[0][0]',
#                                                                   'lambda[0][0]']
#
#  lambda_10 (Lambda)             (None, 15)           0           ['multiply_7[0][0]']
#
#  lambda_11 (Lambda)             (None, 15)           0           ['dense[0][0]']
#
#  multiply_8 (Multiply)          (None, 15)           0           ['lambda_10[0][0]',
#                                                                   'lambda_11[0][0]']
#
#  lambda_12 (Lambda)             (None,)              0           ['multiply_8[0][0]']
#
#  lambda_13 (Lambda)             (None, 1)            0           ['lambda_12[0][0]']
#
# ==================================================================================================
# Total params: 12,512,867
# Trainable params: 12,512,867
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
hist = model.fit(train_data, train_target,
                 validation_data=(valid_data, valid_target),
                 steps_per_epoch=256,
                 validation_steps=256,
                 epochs=30,
                 verbose=1)
# Out:
# Epoch 1/30
# 256/256 [==============================] - 16s 15ms/step - loss: 2.2424 - mse: 8.4719 - mae: 2.2424 - mape: 65.8148 - val_loss: 0.7918 - val_mse: 2.1162 - val_mae: 0.7918 - val_mape: 46.6003
# Epoch 2/30
# 256/256 [==============================] - 4s 14ms/step - loss: 0.7924 - mse: 2.0992 - mae: 0.7924 - mape: 46.8194 - val_loss: 0.8172 - val_mse: 1.9626 - val_mae: 0.8172 - val_mape: 45.8569
# Epoch 3/30
# 256/256 [==============================] - 4s 14ms/step - loss: 0.7385 - mse: 1.6983 - mae: 0.7385 - mape: 41.1623 - val_loss: 0.8374 - val_mse: 1.8701 - val_mae: 0.8374 - val_mape: 44.5338
# Epoch 4/30
# 256/256 [==============================] - 4s 14ms/step - loss: 0.6646 - mse: 1.4270 - mae: 0.6646 - mape: 36.5375 - val_loss: 0.8732 - val_mse: 1.8309 - val_mae: 0.8732 - val_mape: 43.9621
# Epoch 5/30
# 256/256 [==============================] - 4s 14ms/step - loss: 0.6297 - mse: 1.3049 - mae: 0.6297 - mape: 34.1788 - val_loss: 0.8951 - val_mse: 1.8223 - val_mae: 0.8951 - val_mape: 43.6557
# Epoch 6/30
# 256/256 [==============================] - 4s 14ms/step - loss: 0.6073 - mse: 1.2455 - mae: 0.6073 - mape: 32.7337 - val_loss: 0.9061 - val_mse: 1.8195 - val_mae: 0.9061 - val_mape: 43.5129
# Epoch 7/30
# 256/256 [==============================] - 4s 14ms/step - loss: 0.5935 - mse: 1.2057 - mae: 0.5935 - mape: 31.8188 - val_loss: 0.9287 - val_mse: 1.8575 - val_mae: 0.9287 - val_mape: 43.4787
# Epoch 8/30
# 256/256 [==============================] - 4s 14ms/step - loss: 0.5840 - mse: 1.1825 - mae: 0.5840 - mape: 31.1626 - val_loss: 0.9384 - val_mse: 1.8667 - val_mae: 0.9384 - val_mape: 43.4266
# Epoch 9/30
# 256/256 [==============================] - 3s 14ms/step - loss: 0.5754 - mse: 1.1620 - mae: 0.5754 - mape: 30.6166 - val_loss: 0.9438 - val_mse: 1.8618 - val_mae: 0.9438 - val_mape: 43.3954
# Epoch 10/30
# 256/256 [==============================] - 4s 14ms/step - loss: 0.5692 - mse: 1.1461 - mae: 0.5692 - mape: 30.1803 - val_loss: 0.9558 - val_mse: 1.8795 - val_mae: 0.9558 - val_mape: 43.4101
# Epoch 11/30
# 256/256 [==============================] - 4s 14ms/step - loss: 0.5622 - mse: 1.1337 - mae: 0.5622 - mape: 29.7685 - val_loss: 0.9586 - val_mse: 1.8947 - val_mae: 0.9586 - val_mape: 43.4521
# Epoch 12/30
# 256/256 [==============================] - 4s 14ms/step - loss: 0.5586 - mse: 1.1209 - mae: 0.5586 - mape: 29.4927 - val_loss: 0.9657 - val_mse: 1.9078 - val_mae: 0.9657 - val_mape: 43.4885
# Epoch 13/30
# 256/256 [==============================] - 4s 14ms/step - loss: 0.5539 - mse: 1.1114 - mae: 0.5539 - mape: 29.1557 - val_loss: 0.9723 - val_mse: 1.8998 - val_mae: 0.9723 - val_mape: 43.3859
# Epoch 14/30
# 256/256 [==============================] - 4s 14ms/step - loss: 0.5510 - mse: 1.1010 - mae: 0.5510 - mape: 28.8926 - val_loss: 0.9734 - val_mse: 1.9147 - val_mae: 0.9734 - val_mape: 43.4897
# Epoch 15/30
# 256/256 [==============================] - 4s 14ms/step - loss: 0.5468 - mse: 1.0927 - mae: 0.5468 - mape: 28.6310 - val_loss: 0.9769 - val_mse: 1.9192 - val_mae: 0.9769 - val_mape: 43.4930
# Epoch 16/30
# 256/256 [==============================] - 4s 14ms/step - loss: 0.5432 - mse: 1.0838 - mae: 0.5432 - mape: 28.3999 - val_loss: 0.9872 - val_mse: 1.9513 - val_mae: 0.9872 - val_mape: 43.6279
# Epoch 17/30
# 256/256 [==============================] - 4s 14ms/step - loss: 0.5405 - mse: 1.0755 - mae: 0.5405 - mape: 28.1810 - val_loss: 0.9847 - val_mse: 1.9181 - val_mae: 0.9847 - val_mape: 43.4129
# Epoch 18/30
# 256/256 [==============================] - 4s 14ms/step - loss: 0.5374 - mse: 1.0672 - mae: 0.5374 - mape: 27.9525 - val_loss: 0.9829 - val_mse: 1.9194 - val_mae: 0.9829 - val_mape: 43.4688
# Epoch 19/30
# 256/256 [==============================] - 4s 14ms/step - loss: 0.5341 - mse: 1.0616 - mae: 0.5341 - mape: 27.7627 - val_loss: 0.9927 - val_mse: 1.9481 - val_mae: 0.9927 - val_mape: 43.5236
# Epoch 20/30
# 256/256 [==============================] - 4s 14ms/step - loss: 0.5319 - mse: 1.0559 - mae: 0.5319 - mape: 27.5778 - val_loss: 0.9903 - val_mse: 1.9507 - val_mae: 0.9903 - val_mape: 43.5686
# Epoch 21/30
# 256/256 [==============================] - 4s 14ms/step - loss: 0.5286 - mse: 1.0506 - mae: 0.5286 - mape: 27.3959 - val_loss: 0.9926 - val_mse: 1.9575 - val_mae: 0.9926 - val_mape: 43.6066
# Epoch 22/30
# 256/256 [==============================] - 4s 14ms/step - loss: 0.5267 - mse: 1.0449 - mae: 0.5267 - mape: 27.2638 - val_loss: 0.9989 - val_mse: 1.9617 - val_mae: 0.9989 - val_mape: 43.5599
# Epoch 23/30
# 256/256 [==============================] - 4s 14ms/step - loss: 0.5245 - mse: 1.0405 - mae: 0.5245 - mape: 27.1280 - val_loss: 0.9975 - val_mse: 1.9503 - val_mae: 0.9975 - val_mape: 43.5159
# Epoch 24/30
# 256/256 [==============================] - 4s 14ms/step - loss: 0.5235 - mse: 1.0356 - mae: 0.5235 - mape: 27.0038 - val_loss: 0.9995 - val_mse: 1.9563 - val_mae: 0.9995 - val_mape: 43.5066
# Epoch 25/30
# 256/256 [==============================] - 4s 14ms/step - loss: 0.5210 - mse: 1.0312 - mae: 0.5210 - mape: 26.8754 - val_loss: 0.9983 - val_mse: 1.9627 - val_mae: 0.9983 - val_mape: 43.5663
# Epoch 26/30
# 256/256 [==============================] - 4s 14ms/step - loss: 0.5189 - mse: 1.0266 - mae: 0.5189 - mape: 26.7305 - val_loss: 0.9981 - val_mse: 1.9570 - val_mae: 0.9981 - val_mape: 43.5795
# Epoch 27/30
# 256/256 [==============================] - 4s 14ms/step - loss: 0.5178 - mse: 1.0220 - mae: 0.5178 - mape: 26.6508 - val_loss: 1.0033 - val_mse: 1.9656 - val_mae: 1.0033 - val_mape: 43.5707
# Epoch 28/30
# 256/256 [==============================] - 4s 14ms/step - loss: 0.5163 - mse: 1.0166 - mae: 0.5163 - mape: 26.5339 - val_loss: 1.0027 - val_mse: 1.9763 - val_mae: 1.0027 - val_mape: 43.6446
# Epoch 29/30
# 256/256 [==============================] - 4s 14ms/step - loss: 0.5137 - mse: 1.0081 - mae: 0.5137 - mape: 26.3713 - val_loss: 0.9980 - val_mse: 1.9681 - val_mae: 0.9980 - val_mape: 43.6359
# Epoch 30/30
# 256/256 [==============================] - 4s 14ms/step - loss: 0.5110 - mse: 0.9962 - mae: 0.5110 - mape: 26.1895 - val_loss: 0.9960 - val_mse: 1.9611 - val_mae: 0.9960 - val_mape: 43.5763

# %%
# scores = model.evaluate_generator(_evaluate_generator('train_whole_list_5s.txt','test_whole_list_5s.txt'),steps=134103)
# scores = model.evaluate_generator(_evaluate_generator('train_whole_list_10.txt','test_whole_list_10.txt'),steps=34266)
# scores = model.evaluate_generator(_evaluate_generator('train_whole_list_6s.txt','test_whole_list_6s.txt'),steps=134103)
scores = model.evaluate(test_data, test_target, steps=2500)
print(scores)
# Out:
# 2323/2500 [==========================>...] - ETA: 0s - loss: 1.0086 - mse: 2.0098 - mae: 1.0086 - mape: 45.1363WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 2500 batches). You may need to use the repeat() function when building your dataset.
# 2500/2500 [==============================] - 8s 3ms/step - loss: 1.0086 - mse: 2.0090 - mae: 1.0086 - mape: 45.0800
# [1.0086166858673096, 2.00895619392395, 1.0086168050765991, 45.079994201660156]

# %%
# model.save('/content/drive/MyDrive/Colab Notebooks/캡스톤/IMDB_ADLFM_Multi_conv1d')
