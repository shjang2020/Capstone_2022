# %%
import tensorflow as tf
import random
import os
import pickle
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
def seed_everything(seed: int = 42):
    random.seed(seed)
    np.random.seed(seed)
    os.environ["PYTHONHASHSEED"] = str(seed)
    tf.random.set_seed(seed)

seed_everything(42)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip -qq "/content/drive/MyDrive/Colab Notebooks/캡스톤/data/beauty_3.zip"

# %%
with open("./beauty_3/train_id_data.pickle","rb") as fr:
    train_data = pickle.load(fr)
    
with open("./beauty_3/valid_id_data.pickle","rb") as fr:
    valid_data = pickle.load(fr)
    
with open("./beauty_3/test_id_data.pickle","rb") as fr:
    test_data = pickle.load(fr)

# %%
with open("./beauty_3/train_target.pickle","rb") as fr:
    train_target = pickle.load(fr)
    
with open("./beauty_3/valid_target.pickle","rb") as fr:
    valid_target = pickle.load(fr)
    
with open("./beauty_3/test_target.pickle","rb") as fr:
    test_target = pickle.load(fr)

# %%
# ID
train_data[0] = tf.convert_to_tensor(train_data[0], dtype=tf.float32)
train_data[1] = tf.convert_to_tensor(train_data[1], dtype=tf.float32)

# %% [markdown]
# ## Model

# %%
# !pip install keras_multi_head
#!pip install keras_self_attention
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting keras_multi_head
#   Downloading keras-multi-head-0.29.0.tar.gz (13 kB)
# Collecting keras-self-attention==0.51.0
#   Downloading keras-self-attention-0.51.0.tar.gz (11 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from keras-self-attention==0.51.0->keras_multi_head) (1.21.6)
# Building wheels for collected packages: keras-multi-head, keras-self-attention
#   Building wheel for keras-multi-head (setup.py) ... done
#   Created wheel for keras-multi-head: filename=keras_multi_head-0.29.0-py3-none-any.whl size=14993 sha256=46b421d95386e950c650eb0e66fec82a93fb5970a5db6ebe830cd229526bb330
#   Stored in directory: /root/.cache/pip/wheels/86/aa/3c/9d15d24005179dae08ff291ce99c754b296347817d076fd9fb
#   Building wheel for keras-self-attention (setup.py) ... done
#   Created wheel for keras-self-attention: filename=keras_self_attention-0.51.0-py3-none-any.whl size=18912 sha256=b390405a5fa1716b9095d8f4fe984f46bf8d111e0b1ca8743e1a7197ec28b3f8
#   Stored in directory: /root/.cache/pip/wheels/95/b1/a8/5ee00cc137940b2f6fa198212e8f45d813d0e0d9c3a04035a3
# Successfully built keras-multi-head keras-self-attention
# Installing collected packages: keras-self-attention, keras-multi-head
# Successfully installed keras-multi-head-0.29.0 keras-self-attention-0.51.0

# %%
from tensorflow import keras
from keras.layers import Input, Embedding, LSTM, Dense, Lambda, Multiply, Bidirectional, Flatten, BatchNormalization, Add
from keras.layers.convolutional import Conv1D
from keras.layers.pooling import MaxPool1D
from keras.models import Model
from keras.layers.wrappers import TimeDistributed
import numpy as np
import keras.backend as K
from random import randint
from keras_multi_head import MultiHead
#from keras_self_attention import SeqSelfAttention as Attention

import os
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
description_num = 3
#current_path ='data/'
#local_path = 'data/'

# %%
# set parameters:
# V = 142381
# V = 226928
V = 249274 # 48456 #  33531 6158 48456 249274
embedding_dim = 50
max_len = 1 # 1 #  1945 77 1
filters_num = 64
kernel_size = 3

# %%
# description_input=Input(shape=(10,50))
# description_validation=Input(shape=(50,))
input_1 = Input(shape=(description_num, max_len))
input_2 = Input(shape=(max_len,))
embedding = Embedding(input_dim=V,
                      output_dim=embedding_dim,
                      input_length=max_len)
conv1d = Conv1D(filters=filters_num,
                kernel_size=kernel_size,
                activation='relu',
                padding='same')
maxpool1d = MaxPool1D(max_len)
batchnorm1d = BatchNormalization()
dense = Dense(15)

# input_vector=TimeDistributed(embedding)(description_input)
# validation_vector=embedding(description_validation)

input_vector = TimeDistributed(embedding)(input_1)
validation_vector = embedding(input_2)

convolutional_vector = TimeDistributed(MultiHead(conv1d))(input_vector)
validation_conv = MultiHead(conv1d)(validation_vector)
convolutional_vector = tf.keras.backend.squeeze(convolutional_vector, axis=4)
validation_conv = tf.keras.backend.squeeze(validation_conv, axis=3)

maxpooling_vector = TimeDistributed(maxpool1d)(convolutional_vector)
validation_maxpooling = maxpool1d(validation_conv)

middle_output = TimeDistributed(dense)(maxpooling_vector)
middle_validation = dense(validation_maxpooling)

# %%
print(input_vector.shape, validation_vector.shape,
      convolutional_vector.shape, validation_conv.shape,
      maxpooling_vector.shape, validation_maxpooling.shape,
      middle_output.shape, middle_validation.shape)
# Out:
# (None, 3, 1, 50) (None, 1, 50) (None, 3, 1, 64) (None, 1, 64) (None, 3, 1, 64) (None, 1, 64) (None, 3, 1, 15) (None, 1, 15)

# %%
def change_dim_1(X):
    return K.squeeze(X, 1)

def change_dim_2(X):
    return K.squeeze(X, 2)

def repeat(X):
    return K.repeat_elements(X, description_num, 1)

def repeat1(X):
    return K.repeat_elements(X, 15, 2)

def repeat2(X):
    return K.repeat_elements(X, description_num, 1)

def dot(X, Y):
    return K.dot(X, Y)

def sum_item(X):
    return K.sum(X, axis=2)

def sqrt_item(X):
    return K.sqrt(X)

def cal_denominator(X):
    return 1/(X)

def expand_item(X):
    return K.expand_dims(X, 2)

def expand_rate(X):
    return K.expand_dims(X, 1)

def sum_user(X):
    return K.sum(X, 1)

def sum_rate(X):
    return K.sum(X, 1)

def single_exp(X):
    return K.exp(X)

def sum_exp_denominator(X):
    return 1/(K.sum(K.exp(X), 1))

# %%
# def _test_generator(filename):

middle_output_final = Lambda(change_dim_2)(middle_output)#?*10*15
middle_validation_final = Lambda(repeat)(middle_validation)#?*10*15
molecule = Multiply()([middle_output_final, middle_validation_final])
molecule = Lambda(sum_item)(molecule)

denominator1 = Multiply()([middle_output_final, middle_output_final])
denominator1 = Lambda(sum_item)(denominator1)
denominator1 = Lambda(sqrt_item)(denominator1)

denominator2 = Multiply()([middle_validation_final, middle_validation_final])
denominator2 = Lambda(sum_item)(denominator2)
denominator2 = Lambda(sqrt_item)(denominator2)


denominator = Multiply()([denominator1, denominator2])
denominator = Lambda(cal_denominator)(denominator)

similarity = Multiply()([molecule, denominator])
similarity = Lambda(expand_item)(similarity)
similarity = Lambda(repeat1)(similarity)


user = Multiply()([similarity, middle_output_final])
user = Lambda(sum_user)(user)


item = Lambda(change_dim_1)(middle_validation)


rate_hat = Multiply()([user, item])
rate_hat = Lambda(sum_rate)(rate_hat)
rate_hat = Lambda(expand_rate)(rate_hat)

# %%
model = Model(inputs=[input_1, input_2], outputs=rate_hat)
model.compile(optimizer='adam', loss='mae', metrics=['mse', 'mae', 'mape'])

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 3, 1)]       0           []
#
#  input_2 (InputLayer)           [(None, 1)]          0           []
#
#  time_distributed (TimeDistribu  (None, 3, 1, 50)    12463700    ['input_1[0][0]']
#  ted)
#
#  embedding (Embedding)          (None, 1, 50)        12463700    ['input_2[0][0]']
#
#  time_distributed_1 (TimeDistri  (None, 3, 1, 64, 1)  9664       ['time_distributed[0][0]']
#  buted)
#
#  multi_head_1 (MultiHead)       (None, 1, 64, 1)     9664        ['embedding[0][0]']
#
#  tf.compat.v1.squeeze (TFOpLamb  (None, 3, 1, 64)    0           ['time_distributed_1[0][0]']
#  da)
#
#  tf.compat.v1.squeeze_1 (TFOpLa  (None, 1, 64)       0           ['multi_head_1[0][0]']
#  mbda)
#
#  time_distributed_2 (TimeDistri  (None, 3, 1, 64)    0           ['tf.compat.v1.squeeze[0][0]']
#  buted)
#
#  max_pooling1d (MaxPooling1D)   (None, 1, 64)        0           ['tf.compat.v1.squeeze_1[0][0]']
#
#  time_distributed_3 (TimeDistri  (None, 3, 1, 15)    975         ['time_distributed_2[0][0]']
#  buted)
#
#  dense (Dense)                  (None, 1, 15)        975         ['max_pooling1d[0][0]']
#
#  lambda (Lambda)                (None, 3, 15)        0           ['time_distributed_3[0][0]']
#
#  lambda_1 (Lambda)              (None, 3, 15)        0           ['dense[0][0]']
#
#  multiply_1 (Multiply)          (None, 3, 15)        0           ['lambda[0][0]',
#                                                                   'lambda[0][0]']
#
#  multiply_2 (Multiply)          (None, 3, 15)        0           ['lambda_1[0][0]',
#                                                                   'lambda_1[0][0]']
#
#  lambda_3 (Lambda)              (None, 3)            0           ['multiply_1[0][0]']
#
#  lambda_5 (Lambda)              (None, 3)            0           ['multiply_2[0][0]']
#
#  lambda_4 (Lambda)              (None, 3)            0           ['lambda_3[0][0]']
#
#  lambda_6 (Lambda)              (None, 3)            0           ['lambda_5[0][0]']
#
#  multiply (Multiply)            (None, 3, 15)        0           ['lambda[0][0]',
#                                                                   'lambda_1[0][0]']
#
#  multiply_3 (Multiply)          (None, 3)            0           ['lambda_4[0][0]',
#                                                                   'lambda_6[0][0]']
#
#  lambda_2 (Lambda)              (None, 3)            0           ['multiply[0][0]']
#
#  lambda_7 (Lambda)              (None, 3)            0           ['multiply_3[0][0]']
#
#  multiply_4 (Multiply)          (None, 3)            0           ['lambda_2[0][0]',
#                                                                   'lambda_7[0][0]']
#
#  lambda_8 (Lambda)              (None, 3, 1)         0           ['multiply_4[0][0]']
#
#  lambda_9 (Lambda)              (None, 3, 15)        0           ['lambda_8[0][0]']
#
#  multiply_5 (Multiply)          (None, 3, 15)        0           ['lambda_9[0][0]',
#                                                                   'lambda[0][0]']
#
#  lambda_10 (Lambda)             (None, 15)           0           ['multiply_5[0][0]']
#
#  lambda_11 (Lambda)             (None, 15)           0           ['dense[0][0]']
#
#  multiply_6 (Multiply)          (None, 15)           0           ['lambda_10[0][0]',
#                                                                   'lambda_11[0][0]']
#
#  lambda_12 (Lambda)             (None,)              0           ['multiply_6[0][0]']
#
#  lambda_13 (Lambda)             (None, 1)            0           ['lambda_12[0][0]']
#
# ==================================================================================================
# Total params: 12,484,003
# Trainable params: 12,484,003
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
hist = model.fit(train_data, train_target,
                 validation_data=(valid_data, valid_target),
                 steps_per_epoch=256,
                 validation_steps=256,
                 epochs=30,
                 verbose=1)
# Out:
# Epoch 1/30
# 256/256 [==============================] - 17s 15ms/step - loss: 1.3400 - mse: 4.3216 - mae: 1.3400 - mape: 53.9631 - val_loss: 0.7928 - val_mse: 2.1147 - val_mae: 0.7928 - val_mape: 46.6034
# Epoch 2/30
# 256/256 [==============================] - 3s 14ms/step - loss: 0.7853 - mse: 1.9153 - mae: 0.7853 - mape: 45.1300 - val_loss: 0.8228 - val_mse: 1.9083 - val_mae: 0.8228 - val_mape: 45.0644
# Epoch 3/30
# 256/256 [==============================] - 3s 13ms/step - loss: 0.7018 - mse: 1.5138 - mae: 0.7018 - mape: 38.8020 - val_loss: 0.8493 - val_mse: 1.8585 - val_mae: 0.8493 - val_mape: 44.1024
# Epoch 4/30
# 256/256 [==============================] - 3s 13ms/step - loss: 0.6076 - mse: 1.2430 - mae: 0.6076 - mape: 33.3664 - val_loss: 0.8703 - val_mse: 1.9004 - val_mae: 0.8703 - val_mape: 43.8311
# Epoch 5/30
# 256/256 [==============================] - 3s 13ms/step - loss: 0.5496 - mse: 1.0798 - mae: 0.5496 - mape: 29.7028 - val_loss: 0.8805 - val_mse: 1.9455 - val_mae: 0.8805 - val_mape: 43.8752
# Epoch 6/30
# 256/256 [==============================] - 3s 13ms/step - loss: 0.5069 - mse: 0.9782 - mae: 0.5069 - mape: 27.0984 - val_loss: 0.8917 - val_mse: 1.9534 - val_mae: 0.8917 - val_mape: 43.7834
# Epoch 7/30
# 256/256 [==============================] - 3s 13ms/step - loss: 0.4817 - mse: 0.9004 - mae: 0.4817 - mape: 25.4368 - val_loss: 0.9045 - val_mse: 1.9705 - val_mae: 0.9045 - val_mape: 43.7324
# Epoch 8/30
# 256/256 [==============================] - 3s 13ms/step - loss: 0.4549 - mse: 0.8186 - mae: 0.4549 - mape: 23.8604 - val_loss: 0.9119 - val_mse: 1.9522 - val_mae: 0.9119 - val_mape: 43.6227
# Epoch 9/30
# 256/256 [==============================] - 4s 14ms/step - loss: 0.4309 - mse: 0.7502 - mae: 0.4309 - mape: 22.5127 - val_loss: 0.9199 - val_mse: 1.9450 - val_mae: 0.9199 - val_mape: 43.5152
# Epoch 10/30
# 256/256 [==============================] - 3s 13ms/step - loss: 0.4083 - mse: 0.6819 - mae: 0.4083 - mape: 21.1569 - val_loss: 0.9222 - val_mse: 1.9403 - val_mae: 0.9222 - val_mape: 43.5665
# Epoch 11/30
# 256/256 [==============================] - 3s 13ms/step - loss: 0.3886 - mse: 0.6237 - mae: 0.3886 - mape: 19.9863 - val_loss: 0.9387 - val_mse: 1.9213 - val_mae: 0.9387 - val_mape: 43.2962
# Epoch 12/30
# 256/256 [==============================] - 3s 13ms/step - loss: 0.3692 - mse: 0.5700 - mae: 0.3692 - mape: 18.8675 - val_loss: 0.9470 - val_mse: 1.9217 - val_mae: 0.9470 - val_mape: 43.2378
# Epoch 13/30
# 256/256 [==============================] - 3s 13ms/step - loss: 0.3516 - mse: 0.5210 - mae: 0.3516 - mape: 17.8188 - val_loss: 0.9534 - val_mse: 1.9291 - val_mae: 0.9534 - val_mape: 43.1787
# Epoch 14/30
# 256/256 [==============================] - 3s 14ms/step - loss: 0.3351 - mse: 0.4776 - mae: 0.3351 - mape: 16.8794 - val_loss: 0.9581 - val_mse: 1.9290 - val_mae: 0.9581 - val_mape: 43.2314
# Epoch 15/30
# 256/256 [==============================] - 3s 13ms/step - loss: 0.3208 - mse: 0.4397 - mae: 0.3208 - mape: 16.0682 - val_loss: 0.9629 - val_mse: 1.9531 - val_mae: 0.9629 - val_mape: 43.2737
# Epoch 16/30
# 256/256 [==============================] - 4s 14ms/step - loss: 0.3075 - mse: 0.4056 - mae: 0.3075 - mape: 15.3042 - val_loss: 0.9728 - val_mse: 1.9310 - val_mae: 0.9728 - val_mape: 43.0856
# Epoch 17/30
# 256/256 [==============================] - 3s 14ms/step - loss: 0.2953 - mse: 0.3764 - mae: 0.2953 - mape: 14.6247 - val_loss: 0.9693 - val_mse: 1.9246 - val_mae: 0.9693 - val_mape: 43.0994
# Epoch 18/30
# 256/256 [==============================] - 3s 13ms/step - loss: 0.2844 - mse: 0.3504 - mae: 0.2844 - mape: 13.9952 - val_loss: 0.9670 - val_mse: 1.9461 - val_mae: 0.9670 - val_mape: 43.3619
# Epoch 19/30
# 256/256 [==============================] - 3s 13ms/step - loss: 0.2751 - mse: 0.3279 - mae: 0.2751 - mape: 13.4720 - val_loss: 0.9717 - val_mse: 1.9428 - val_mae: 0.9717 - val_mape: 43.1939
# Epoch 20/30
# 256/256 [==============================] - 3s 13ms/step - loss: 0.2646 - mse: 0.3066 - mae: 0.2646 - mape: 12.9060 - val_loss: 0.9735 - val_mse: 1.9522 - val_mae: 0.9735 - val_mape: 43.2547
# Epoch 21/30
# 256/256 [==============================] - 3s 13ms/step - loss: 0.2566 - mse: 0.2886 - mae: 0.2566 - mape: 12.4698 - val_loss: 0.9840 - val_mse: 1.9485 - val_mae: 0.9840 - val_mape: 43.0525
# Epoch 22/30
# 256/256 [==============================] - 3s 13ms/step - loss: 0.2475 - mse: 0.2711 - mae: 0.2475 - mape: 11.9882 - val_loss: 0.9829 - val_mse: 1.9336 - val_mae: 0.9829 - val_mape: 43.0303
# Epoch 23/30
# 256/256 [==============================] - 3s 13ms/step - loss: 0.2405 - mse: 0.2572 - mae: 0.2405 - mape: 11.6111 - val_loss: 0.9797 - val_mse: 1.9419 - val_mae: 0.9797 - val_mape: 43.1830
# Epoch 24/30
# 256/256 [==============================] - 3s 13ms/step - loss: 0.2332 - mse: 0.2433 - mae: 0.2332 - mape: 11.2119 - val_loss: 0.9824 - val_mse: 1.9481 - val_mae: 0.9824 - val_mape: 43.1624
# Epoch 25/30
# 256/256 [==============================] - 3s 14ms/step - loss: 0.2276 - mse: 0.2324 - mae: 0.2276 - mape: 10.9083 - val_loss: 0.9873 - val_mse: 1.9485 - val_mae: 0.9873 - val_mape: 43.1853
# Epoch 26/30
# 256/256 [==============================] - 3s 13ms/step - loss: 0.2224 - mse: 0.2207 - mae: 0.2224 - mape: 10.5668 - val_loss: 0.9954 - val_mse: 1.9302 - val_mae: 0.9954 - val_mape: 42.9386
# Epoch 27/30
# 256/256 [==============================] - 3s 13ms/step - loss: 0.2171 - mse: 0.2106 - mae: 0.2171 - mape: 10.2680 - val_loss: 0.9887 - val_mse: 1.9521 - val_mae: 0.9887 - val_mape: 43.1794
# Epoch 28/30
# 256/256 [==============================] - 3s 13ms/step - loss: 0.2119 - mse: 0.2015 - mae: 0.2119 - mape: 9.9849 - val_loss: 0.9934 - val_mse: 1.9503 - val_mae: 0.9934 - val_mape: 43.1275
# Epoch 29/30
# 256/256 [==============================] - 3s 13ms/step - loss: 0.2072 - mse: 0.1930 - mae: 0.2072 - mape: 9.7302 - val_loss: 0.9936 - val_mse: 1.9503 - val_mae: 0.9936 - val_mape: 43.1659
# Epoch 30/30
# 256/256 [==============================] - 3s 13ms/step - loss: 0.2037 - mse: 0.1860 - mae: 0.2037 - mape: 9.5115 - val_loss: 1.0024 - val_mse: 1.9463 - val_mae: 1.0024 - val_mape: 43.0178

# %%
# scores = model.evaluate_generator(_evaluate_generator('train_whole_list_5s.txt','test_whole_list_5s.txt'),steps=134103)
# scores = model.evaluate_generator(_evaluate_generator('train_whole_list_10.txt','test_whole_list_10.txt'),steps=34266)
# scores = model.evaluate_generator(_evaluate_generator('train_whole_list_6s.txt','test_whole_list_6s.txt'),steps=134103)
scores = model.evaluate(test_data, test_target, steps=2500)
print(scores)
# Out:
# 2328/2500 [==========================>...] - ETA: 0s - loss: 1.0231 - mse: 2.0188 - mae: 1.0231 - mape: 44.8692WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 2500 batches). You may need to use the repeat() function when building your dataset.
# 2500/2500 [==============================] - 10s 4ms/step - loss: 1.0227 - mse: 2.0170 - mae: 1.0227 - mape: 44.8289
# [1.0226753950119019, 2.017009973526001, 1.0226753950119019, 44.82888412475586]

# %%
# model.save(path+"IMDB_ADLFM_Multi_head_conv1d")
