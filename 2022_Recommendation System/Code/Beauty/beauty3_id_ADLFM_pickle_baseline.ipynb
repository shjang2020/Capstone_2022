# %%
import tensorflow as tf
import random
import os
import pickle
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
def seed_everything(seed: int = 42):
    random.seed(seed)
    np.random.seed(seed)
    os.environ["PYTHONHASHSEED"] = str(seed)
    tf.random.set_seed(seed)

seed_everything(42)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip -qq "/content/drive/MyDrive/Colab Notebooks/캡스톤/data/beauty_3.zip"

# %%
with open("./beauty_3/train_id_data.pickle","rb") as fr:
    train_data = pickle.load(fr)
    
with open("./beauty_3/valid_id_data.pickle","rb") as fr:
    valid_data = pickle.load(fr)
    
with open("./beauty_3/test_id_data.pickle","rb") as fr:
    test_data = pickle.load(fr)

# %%
with open("./beauty_3/train_target.pickle","rb") as fr:
    train_target = pickle.load(fr)
    
with open("./beauty_3/valid_target.pickle","rb") as fr:
    valid_target = pickle.load(fr)
    
with open("./beauty_3/test_target.pickle","rb") as fr:
    test_target = pickle.load(fr)

# %%
len(train_target)
# Out:
# 150000

# %% [markdown]
# ## Model

# %%
from tensorflow import keras
from keras.layers import Input, Embedding, LSTM, Dense, Lambda, Multiply, Bidirectional, Flatten, BatchNormalization, Add
from keras.layers.convolutional import Conv1D
from keras.layers.pooling import MaxPool1D
from keras.models import Model
from keras.layers.wrappers import TimeDistributed
import numpy as np
import keras.backend as K
from random import randint

import os
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
description_num = 3
#current_path ='data/'
#local_path = 'data/'

# %%
# set parameters:
# V = 142381
# V = 226928
V = 249274  #33531 # len(tokenizer.word_index) #249274
embedding_dim = 50
max_len =  1   # 1945  # maxlen
filters_num = 64
kernel_size = 3

# %%
# description_input=Input(shape=(10,50))
# description_validation=Input(shape=(50,))

input_1 = Input(shape=(description_num, max_len))
input_2 = Input(shape=(max_len,))
embedding = Embedding(input_dim=V,
                      output_dim=embedding_dim,
                      input_length=max_len)
conv1d = Conv1D(filters=filters_num,
                kernel_size=kernel_size,
                activation='relu',
                padding='same'
                )
maxpool1d = MaxPool1D(max_len)
dense = Dense(15)

# input_vector=TimeDistributed(embedding)(description_input)
# validation_vector=embedding(description_validation)

input_vector = TimeDistributed(embedding)(input_1)
validation_vector = embedding(input_2)

convolutional_vector = TimeDistributed(conv1d)(input_vector)
validation_conv = conv1d(validation_vector)

maxpooling_vector = TimeDistributed(maxpool1d)(convolutional_vector)
validation_maxpooling = maxpool1d(validation_conv)

middle_output = TimeDistributed(dense)(maxpooling_vector)
middle_validation = dense(validation_maxpooling)

# %%
print(input_vector.shape, validation_vector.shape,
      convolutional_vector.shape, validation_conv.shape,
      maxpooling_vector.shape, validation_maxpooling.shape,
      middle_output.shape, middle_validation.shape)
# Out:
# (None, 3, 1, 50) (None, 1, 50) (None, 3, 1, 64) (None, 1, 64) (None, 3, 1, 64) (None, 1, 64) (None, 3, 1, 15) (None, 1, 15)

# %%
def change_dim_1(X):
    return K.squeeze(X, 1)

def change_dim_2(X):
    return K.squeeze(X, 2)

def repeat(X):
    return K.repeat_elements(X, description_num, 1)

def repeat1(X):
    return K.repeat_elements(X, 15, 2)

def repeat2(X):
    return K.repeat_elements(X, description_num, 1)

def dot(X, Y):
    return K.dot(X, Y)

def sum_item(X):
    return K.sum(X, axis=2)

def sqrt_item(X):
    return K.sqrt(X)

def cal_denominator(X):
    return 1/(X)

def expand_item(X):
    return K.expand_dims(X, 2)

def expand_rate(X):
    return K.expand_dims(X, 1)

def sum_user(X):
    return K.sum(X, 1)

def sum_rate(X):
    return K.sum(X, 1)

def single_exp(X):
    return K.exp(X)

def sum_exp_denominator(X):
    return 1/(K.sum(K.exp(X), 1))

# %%
# def _test_generator(filename):

middle_output_final = Lambda(change_dim_2)(middle_output)#?*10*15
middle_validation_final = Lambda(repeat)(middle_validation)#?*10*15
molecule = Multiply()([middle_output_final, middle_validation_final])
molecule = Lambda(sum_item)(molecule)

denominator1 = Multiply()([middle_output_final, middle_output_final])
denominator1 = Lambda(sum_item)(denominator1)
denominator1 = Lambda(sqrt_item)(denominator1)

denominator2 = Multiply()([middle_validation_final, middle_validation_final])
denominator2 = Lambda(sum_item)(denominator2)
denominator2 = Lambda(sqrt_item)(denominator2)


denominator = Multiply()([denominator1, denominator2])
denominator = Lambda(cal_denominator)(denominator)

similarity = Multiply()([molecule, denominator])
similarity = Lambda(expand_item)(similarity)
similarity = Lambda(repeat1)(similarity)


user = Multiply()([similarity, middle_output_final])
user = Lambda(sum_user)(user)


item = Lambda(change_dim_1)(middle_validation)


rate_hat = Multiply()([user, item])
rate_hat = Lambda(sum_rate)(rate_hat)
rate_hat = Lambda(expand_rate)(rate_hat)

# %%
model = Model(inputs=[input_1, input_2], outputs=rate_hat)
model.compile(optimizer='adam', loss='mae', metrics=['mse', 'mae', 'mape'])

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 3, 1)]       0           []
#
#  input_2 (InputLayer)           [(None, 1)]          0           []
#
#  time_distributed (TimeDistribu  (None, 3, 1, 50)    12463700    ['input_1[0][0]']
#  ted)
#
#  embedding (Embedding)          (None, 1, 50)        12463700    ['input_2[0][0]']
#
#  time_distributed_1 (TimeDistri  (None, 3, 1, 64)    9664        ['time_distributed[0][0]']
#  buted)
#
#  conv1d (Conv1D)                (None, 1, 64)        9664        ['embedding[0][0]']
#
#  time_distributed_2 (TimeDistri  (None, 3, 1, 64)    0           ['time_distributed_1[0][0]']
#  buted)
#
#  max_pooling1d (MaxPooling1D)   (None, 1, 64)        0           ['conv1d[0][0]']
#
#  time_distributed_3 (TimeDistri  (None, 3, 1, 15)    975         ['time_distributed_2[0][0]']
#  buted)
#
#  dense (Dense)                  (None, 1, 15)        975         ['max_pooling1d[0][0]']
#
#  lambda (Lambda)                (None, 3, 15)        0           ['time_distributed_3[0][0]']
#
#  lambda_1 (Lambda)              (None, 3, 15)        0           ['dense[0][0]']
#
#  multiply_1 (Multiply)          (None, 3, 15)        0           ['lambda[0][0]',
#                                                                   'lambda[0][0]']
#
#  multiply_2 (Multiply)          (None, 3, 15)        0           ['lambda_1[0][0]',
#                                                                   'lambda_1[0][0]']
#
#  lambda_3 (Lambda)              (None, 3)            0           ['multiply_1[0][0]']
#
#  lambda_5 (Lambda)              (None, 3)            0           ['multiply_2[0][0]']
#
#  lambda_4 (Lambda)              (None, 3)            0           ['lambda_3[0][0]']
#
#  lambda_6 (Lambda)              (None, 3)            0           ['lambda_5[0][0]']
#
#  multiply (Multiply)            (None, 3, 15)        0           ['lambda[0][0]',
#                                                                   'lambda_1[0][0]']
#
#  multiply_3 (Multiply)          (None, 3)            0           ['lambda_4[0][0]',
#                                                                   'lambda_6[0][0]']
#
#  lambda_2 (Lambda)              (None, 3)            0           ['multiply[0][0]']
#
#  lambda_7 (Lambda)              (None, 3)            0           ['multiply_3[0][0]']
#
#  multiply_4 (Multiply)          (None, 3)            0           ['lambda_2[0][0]',
#                                                                   'lambda_7[0][0]']
#
#  lambda_8 (Lambda)              (None, 3, 1)         0           ['multiply_4[0][0]']
#
#  lambda_9 (Lambda)              (None, 3, 15)        0           ['lambda_8[0][0]']
#
#  multiply_5 (Multiply)          (None, 3, 15)        0           ['lambda_9[0][0]',
#                                                                   'lambda[0][0]']
#
#  lambda_10 (Lambda)             (None, 15)           0           ['multiply_5[0][0]']
#
#  lambda_11 (Lambda)             (None, 15)           0           ['dense[0][0]']
#
#  multiply_6 (Multiply)          (None, 15)           0           ['lambda_10[0][0]',
#                                                                   'lambda_11[0][0]']
#
#  lambda_12 (Lambda)             (None,)              0           ['multiply_6[0][0]']
#
#  lambda_13 (Lambda)             (None, 1)            0           ['lambda_12[0][0]']
#
# ==================================================================================================
# Total params: 12,474,339
# Trainable params: 12,474,339
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
hist = model.fit(train_data, train_target,
                 validation_data=(valid_data, valid_target),
                 steps_per_epoch=256,
                 validation_steps=256,
                 epochs=30,
                 verbose=1)
# Out:
# Epoch 1/30
# 256/256 [==============================] - 17s 15ms/step - loss: 1.3120 - mse: 4.1498 - mae: 1.3120 - mape: 53.3960 - val_loss: 0.7922 - val_mse: 2.1477 - val_mae: 0.7922 - val_mape: 46.7991
# Epoch 2/30
# 256/256 [==============================] - 3s 14ms/step - loss: 0.7920 - mse: 2.0070 - mae: 0.7920 - mape: 46.1082 - val_loss: 0.8226 - val_mse: 1.9131 - val_mae: 0.8226 - val_mape: 45.0546
# Epoch 3/30
# 256/256 [==============================] - 3s 13ms/step - loss: 0.7223 - mse: 1.5756 - mae: 0.7223 - mape: 39.9908 - val_loss: 0.8401 - val_mse: 1.8535 - val_mae: 0.8401 - val_mape: 44.3460
# Epoch 4/30
# 256/256 [==============================] - 3s 13ms/step - loss: 0.6604 - mse: 1.3918 - mae: 0.6604 - mape: 36.0643 - val_loss: 0.8707 - val_mse: 1.8501 - val_mae: 0.8707 - val_mape: 43.8981
# Epoch 5/30
# 256/256 [==============================] - 3s 13ms/step - loss: 0.6304 - mse: 1.3044 - mae: 0.6304 - mape: 34.0477 - val_loss: 0.8769 - val_mse: 1.8592 - val_mae: 0.8769 - val_mape: 43.9123
# Epoch 6/30
# 256/256 [==============================] - 3s 13ms/step - loss: 0.6110 - mse: 1.2263 - mae: 0.6110 - mape: 32.5359 - val_loss: 0.8826 - val_mse: 1.8730 - val_mae: 0.8826 - val_mape: 43.9049
# Epoch 7/30
# 256/256 [==============================] - 3s 13ms/step - loss: 0.5898 - mse: 1.1344 - mae: 0.5898 - mape: 30.9808 - val_loss: 0.9009 - val_mse: 1.8619 - val_mae: 0.9009 - val_mape: 43.6764
# Epoch 8/30
# 256/256 [==============================] - 3s 13ms/step - loss: 0.5652 - mse: 1.0309 - mae: 0.5652 - mape: 29.3343 - val_loss: 0.9205 - val_mse: 1.8391 - val_mae: 0.9205 - val_mape: 43.4333
# Epoch 9/30
# 256/256 [==============================] - 3s 13ms/step - loss: 0.5389 - mse: 0.9274 - mae: 0.5389 - mape: 27.6349 - val_loss: 0.9244 - val_mse: 1.8778 - val_mae: 0.9244 - val_mape: 43.6977
# Epoch 10/30
# 256/256 [==============================] - 3s 13ms/step - loss: 0.5107 - mse: 0.8324 - mae: 0.5107 - mape: 26.0112 - val_loss: 0.9433 - val_mse: 1.8468 - val_mae: 0.9433 - val_mape: 43.4041
# Epoch 11/30
# 256/256 [==============================] - 3s 13ms/step - loss: 0.4839 - mse: 0.7481 - mae: 0.4839 - mape: 24.4601 - val_loss: 0.9588 - val_mse: 1.8627 - val_mae: 0.9588 - val_mape: 43.3748
# Epoch 12/30
# 256/256 [==============================] - 3s 13ms/step - loss: 0.4593 - mse: 0.6773 - mae: 0.4593 - mape: 23.1184 - val_loss: 0.9725 - val_mse: 1.8647 - val_mae: 0.9725 - val_mape: 43.3475
# Epoch 13/30
# 256/256 [==============================] - 3s 13ms/step - loss: 0.4382 - mse: 0.6198 - mae: 0.4382 - mape: 21.9405 - val_loss: 0.9694 - val_mse: 1.8649 - val_mae: 0.9694 - val_mape: 43.4993
# Epoch 14/30
# 256/256 [==============================] - 3s 13ms/step - loss: 0.4185 - mse: 0.5712 - mae: 0.4185 - mape: 20.9211 - val_loss: 0.9795 - val_mse: 1.8714 - val_mae: 0.9795 - val_mape: 43.4766
# Epoch 15/30
# 256/256 [==============================] - 3s 13ms/step - loss: 0.4020 - mse: 0.5316 - mae: 0.4020 - mape: 20.0222 - val_loss: 0.9808 - val_mse: 1.8694 - val_mae: 0.9808 - val_mape: 43.4749
# Epoch 16/30
# 256/256 [==============================] - 3s 13ms/step - loss: 0.3877 - mse: 0.4988 - mae: 0.3877 - mape: 19.2926 - val_loss: 0.9893 - val_mse: 1.8812 - val_mae: 0.9893 - val_mape: 43.5502
# Epoch 17/30
# 256/256 [==============================] - 3s 13ms/step - loss: 0.3748 - mse: 0.4725 - mae: 0.3748 - mape: 18.6478 - val_loss: 0.9974 - val_mse: 1.8839 - val_mae: 0.9974 - val_mape: 43.4484
# Epoch 18/30
# 256/256 [==============================] - 3s 13ms/step - loss: 0.3638 - mse: 0.4489 - mae: 0.3638 - mape: 18.0737 - val_loss: 1.0015 - val_mse: 1.8917 - val_mae: 1.0015 - val_mape: 43.5308
# Epoch 19/30
# 256/256 [==============================] - 3s 13ms/step - loss: 0.3536 - mse: 0.4298 - mae: 0.3536 - mape: 17.5719 - val_loss: 1.0105 - val_mse: 1.9321 - val_mae: 1.0105 - val_mape: 43.7101
# Epoch 20/30
# 256/256 [==============================] - 3s 13ms/step - loss: 0.3460 - mse: 0.4134 - mae: 0.3460 - mape: 17.1674 - val_loss: 1.0089 - val_mse: 1.9121 - val_mae: 1.0089 - val_mape: 43.5908
# Epoch 21/30
# 256/256 [==============================] - 3s 14ms/step - loss: 0.3378 - mse: 0.3981 - mae: 0.3378 - mape: 16.7803 - val_loss: 1.0123 - val_mse: 1.9159 - val_mae: 1.0123 - val_mape: 43.6621
# Epoch 22/30
# 256/256 [==============================] - 3s 14ms/step - loss: 0.3303 - mse: 0.3852 - mae: 0.3303 - mape: 16.4205 - val_loss: 1.0168 - val_mse: 1.9513 - val_mae: 1.0168 - val_mape: 43.9104
# Epoch 23/30
# 256/256 [==============================] - 3s 14ms/step - loss: 0.3248 - mse: 0.3745 - mae: 0.3248 - mape: 16.1577 - val_loss: 1.0219 - val_mse: 1.9304 - val_mae: 1.0219 - val_mape: 43.6419
# Epoch 24/30
# 256/256 [==============================] - 3s 13ms/step - loss: 0.3193 - mse: 0.3648 - mae: 0.3193 - mape: 15.8900 - val_loss: 1.0219 - val_mse: 1.9213 - val_mae: 1.0219 - val_mape: 43.5750
# Epoch 25/30
# 256/256 [==============================] - 3s 13ms/step - loss: 0.3146 - mse: 0.3559 - mae: 0.3146 - mape: 15.6500 - val_loss: 1.0252 - val_mse: 1.9155 - val_mae: 1.0252 - val_mape: 43.5719
# Epoch 26/30
# 256/256 [==============================] - 3s 13ms/step - loss: 0.3088 - mse: 0.3485 - mae: 0.3088 - mape: 15.4235 - val_loss: 1.0262 - val_mse: 1.9598 - val_mae: 1.0262 - val_mape: 43.9107
# Epoch 27/30
# 256/256 [==============================] - 3s 13ms/step - loss: 0.3050 - mse: 0.3414 - mae: 0.3050 - mape: 15.2328 - val_loss: 1.0283 - val_mse: 1.9458 - val_mae: 1.0283 - val_mape: 43.7069
# Epoch 28/30
# 256/256 [==============================] - 3s 13ms/step - loss: 0.3009 - mse: 0.3346 - mae: 0.3009 - mape: 15.0516 - val_loss: 1.0284 - val_mse: 1.9589 - val_mae: 1.0284 - val_mape: 43.8529
# Epoch 29/30
# 256/256 [==============================] - 3s 13ms/step - loss: 0.2969 - mse: 0.3285 - mae: 0.2969 - mape: 14.8814 - val_loss: 1.0321 - val_mse: 1.9555 - val_mae: 1.0321 - val_mape: 43.7822
# Epoch 30/30
# 256/256 [==============================] - 3s 13ms/step - loss: 0.2930 - mse: 0.3238 - mae: 0.2930 - mape: 14.7273 - val_loss: 1.0310 - val_mse: 1.9470 - val_mae: 1.0310 - val_mape: 43.7258

# %%
# scores = model.evaluate_generator(_evaluate_generator('train_whole_list_5s.txt','test_whole_list_5s.txt'),steps=134103)
# scores = model.evaluate_generator(_evaluate_generator('train_whole_list_10.txt','test_whole_list_10.txt'),steps=34266)
# scores = model.evaluate_generator(_evaluate_generator('train_whole_list_6s.txt','test_whole_list_6s.txt'),steps=134103)
scores = model.evaluate(test_data, test_target, steps=2500)
print(scores)
# Out:
# 2333/2500 [==========================>...] - ETA: 0s - loss: 1.0456 - mse: 2.0042 - mae: 1.0456 - mape: 45.5555WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 2500 batches). You may need to use the repeat() function when building your dataset.
# 2500/2500 [==============================] - 10s 4ms/step - loss: 1.0456 - mse: 2.0040 - mae: 1.0456 - mape: 45.5515
# [1.0455505847930908, 2.004009485244751, 1.0455505847930908, 45.5515251159668]

# %%
#model.save(path+"IMDB_ADLFM_baseline")
# Out:
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab Notebooks/캡스톤/data/IMDB_ADLFM_baseline/assets
