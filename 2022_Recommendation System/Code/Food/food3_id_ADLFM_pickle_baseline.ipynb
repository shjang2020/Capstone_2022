# %%
import tensorflow as tf
import random
import os
import pickle
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
def seed_everything(seed: int = 42):
    random.seed(seed)
    np.random.seed(seed)
    os.environ["PYTHONHASHSEED"] = str(seed)
    tf.random.set_seed(seed)

seed_everything(42)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip -qq "/content/drive/MyDrive/Colab Notebooks/캡스톤/data/food_3.zip"

# %%
with open("./food_3/train_id_data.pickle","rb") as fr:
    train_data = pickle.load(fr)
    
with open("./food_3/valid_id_data.pickle","rb") as fr:
    valid_data = pickle.load(fr)
    
with open("./food_3/test_id_data.pickle","rb") as fr:
    test_data = pickle.load(fr)

# %%
with open("./food_3/train_target.pickle","rb") as fr:
    train_target = pickle.load(fr)
    
with open("./food_3/valid_target.pickle","rb") as fr:
    valid_target = pickle.load(fr)
    
with open("./food_3/test_target.pickle","rb") as fr:
    test_target = pickle.load(fr)

# %%
len(train_target)+len(valid_target)+len(test_target)
# Out:
# 130524

# %% [markdown]
# ## Model

# %%
from tensorflow import keras
from keras.layers import Input, Embedding, LSTM, Dense, Lambda, Multiply, Bidirectional, Flatten, BatchNormalization, Add
from keras.layers.convolutional import Conv1D
from keras.layers.pooling import MaxPool1D
from keras.models import Model
from keras.layers.wrappers import TimeDistributed
import numpy as np
import keras.backend as K
from random import randint

import os
os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
description_num = 3
#current_path ='data/'
#local_path = 'data/'

# %%
# set parameters:
# V = 142381
# V = 226928
V = 74258  #33531 # len(tokenizer.word_index) #249274
embedding_dim = 50
max_len =  1   # 1945  # maxlen
filters_num = 64
kernel_size = 3

# %%
# description_input=Input(shape=(10,50))
# description_validation=Input(shape=(50,))

input_1 = Input(shape=(description_num, max_len))
input_2 = Input(shape=(max_len,))
embedding = Embedding(input_dim=V,
                      output_dim=embedding_dim,
                      input_length=max_len)
conv1d = Conv1D(filters=filters_num,
                kernel_size=kernel_size,
                activation='relu',
                padding='same'
                )
maxpool1d = MaxPool1D(max_len)
dense = Dense(15)

# input_vector=TimeDistributed(embedding)(description_input)
# validation_vector=embedding(description_validation)

input_vector = TimeDistributed(embedding)(input_1)
validation_vector = embedding(input_2)

convolutional_vector = TimeDistributed(conv1d)(input_vector)
validation_conv = conv1d(validation_vector)

maxpooling_vector = TimeDistributed(maxpool1d)(convolutional_vector)
validation_maxpooling = maxpool1d(validation_conv)

middle_output = TimeDistributed(dense)(maxpooling_vector)
middle_validation = dense(validation_maxpooling)

# %%
print(input_vector.shape, validation_vector.shape,
      convolutional_vector.shape, validation_conv.shape,
      maxpooling_vector.shape, validation_maxpooling.shape,
      middle_output.shape, middle_validation.shape)
# Out:
# (None, 3, 1, 50) (None, 1, 50) (None, 3, 1, 64) (None, 1, 64) (None, 3, 1, 64) (None, 1, 64) (None, 3, 1, 15) (None, 1, 15)

# %%
def change_dim_1(X):
    return K.squeeze(X, 1)

def change_dim_2(X):
    return K.squeeze(X, 2)

def repeat(X):
    return K.repeat_elements(X, description_num, 1)

def repeat1(X):
    return K.repeat_elements(X, 15, 2)

def repeat2(X):
    return K.repeat_elements(X, description_num, 1)

def dot(X, Y):
    return K.dot(X, Y)

def sum_item(X):
    return K.sum(X, axis=2)

def sqrt_item(X):
    return K.sqrt(X)

def cal_denominator(X):
    return 1/(X)

def expand_item(X):
    return K.expand_dims(X, 2)

def expand_rate(X):
    return K.expand_dims(X, 1)

def sum_user(X):
    return K.sum(X, 1)

def sum_rate(X):
    return K.sum(X, 1)

def single_exp(X):
    return K.exp(X)

def sum_exp_denominator(X):
    return 1/(K.sum(K.exp(X), 1))

# %%
# def _test_generator(filename):

middle_output_final = Lambda(change_dim_2)(middle_output)#?*10*15
middle_validation_final = Lambda(repeat)(middle_validation)#?*10*15
molecule = Multiply()([middle_output_final, middle_validation_final])
molecule = Lambda(sum_item)(molecule)

denominator1 = Multiply()([middle_output_final, middle_output_final])
denominator1 = Lambda(sum_item)(denominator1)
denominator1 = Lambda(sqrt_item)(denominator1)

denominator2 = Multiply()([middle_validation_final, middle_validation_final])
denominator2 = Lambda(sum_item)(denominator2)
denominator2 = Lambda(sqrt_item)(denominator2)


denominator = Multiply()([denominator1, denominator2])
denominator = Lambda(cal_denominator)(denominator)

similarity = Multiply()([molecule, denominator])
similarity = Lambda(expand_item)(similarity)
similarity = Lambda(repeat1)(similarity)


user = Multiply()([similarity, middle_output_final])
user = Lambda(sum_user)(user)


item = Lambda(change_dim_1)(middle_validation)


rate_hat = Multiply()([user, item])
rate_hat = Lambda(sum_rate)(rate_hat)
rate_hat = Lambda(expand_rate)(rate_hat)

# %%
model = Model(inputs=[input_1, input_2], outputs=rate_hat)
model.compile(optimizer='adam', loss='mae', metrics=['mse', 'mae', 'mape'])

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 3, 1)]       0           []
#
#  input_2 (InputLayer)           [(None, 1)]          0           []
#
#  time_distributed (TimeDistribu  (None, 3, 1, 50)    3712900     ['input_1[0][0]']
#  ted)
#
#  embedding (Embedding)          (None, 1, 50)        3712900     ['input_2[0][0]']
#
#  time_distributed_1 (TimeDistri  (None, 3, 1, 64)    9664        ['time_distributed[0][0]']
#  buted)
#
#  conv1d (Conv1D)                (None, 1, 64)        9664        ['embedding[0][0]']
#
#  time_distributed_2 (TimeDistri  (None, 3, 1, 64)    0           ['time_distributed_1[0][0]']
#  buted)
#
#  max_pooling1d (MaxPooling1D)   (None, 1, 64)        0           ['conv1d[0][0]']
#
#  time_distributed_3 (TimeDistri  (None, 3, 1, 15)    975         ['time_distributed_2[0][0]']
#  buted)
#
#  dense (Dense)                  (None, 1, 15)        975         ['max_pooling1d[0][0]']
#
#  lambda (Lambda)                (None, 3, 15)        0           ['time_distributed_3[0][0]']
#
#  lambda_1 (Lambda)              (None, 3, 15)        0           ['dense[0][0]']
#
#  multiply_1 (Multiply)          (None, 3, 15)        0           ['lambda[0][0]',
#                                                                   'lambda[0][0]']
#
#  multiply_2 (Multiply)          (None, 3, 15)        0           ['lambda_1[0][0]',
#                                                                   'lambda_1[0][0]']
#
#  lambda_3 (Lambda)              (None, 3)            0           ['multiply_1[0][0]']
#
#  lambda_5 (Lambda)              (None, 3)            0           ['multiply_2[0][0]']
#
#  lambda_4 (Lambda)              (None, 3)            0           ['lambda_3[0][0]']
#
#  lambda_6 (Lambda)              (None, 3)            0           ['lambda_5[0][0]']
#
#  multiply (Multiply)            (None, 3, 15)        0           ['lambda[0][0]',
#                                                                   'lambda_1[0][0]']
#
#  multiply_3 (Multiply)          (None, 3)            0           ['lambda_4[0][0]',
#                                                                   'lambda_6[0][0]']
#
#  lambda_2 (Lambda)              (None, 3)            0           ['multiply[0][0]']
#
#  lambda_7 (Lambda)              (None, 3)            0           ['multiply_3[0][0]']
#
#  multiply_4 (Multiply)          (None, 3)            0           ['lambda_2[0][0]',
#                                                                   'lambda_7[0][0]']
#
#  lambda_8 (Lambda)              (None, 3, 1)         0           ['multiply_4[0][0]']
#
#  lambda_9 (Lambda)              (None, 3, 15)        0           ['lambda_8[0][0]']
#
#  multiply_5 (Multiply)          (None, 3, 15)        0           ['lambda_9[0][0]',
#                                                                   'lambda[0][0]']
#
#  lambda_10 (Lambda)             (None, 15)           0           ['multiply_5[0][0]']
#
#  lambda_11 (Lambda)             (None, 15)           0           ['dense[0][0]']
#
#  multiply_6 (Multiply)          (None, 15)           0           ['lambda_10[0][0]',
#                                                                   'lambda_11[0][0]']
#
#  lambda_12 (Lambda)             (None,)              0           ['multiply_6[0][0]']
#
#  lambda_13 (Lambda)             (None, 1)            0           ['lambda_12[0][0]']
#
# ==================================================================================================
# Total params: 3,723,539
# Trainable params: 3,723,539
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
hist = model.fit(train_data, train_target,
                 validation_data=(valid_data, valid_target),
                 steps_per_epoch=256,
                 validation_steps=256,
                 epochs=30,
                 verbose=1)
# Out:
# Epoch 1/30
# 256/256 [==============================] - 16s 11ms/step - loss: 1.2943 - mse: 4.1530 - mae: 1.2943 - mape: 56.8129 - val_loss: 0.7893 - val_mse: 2.1762 - val_mae: 0.7893 - val_mape: 50.0624
# Epoch 2/30
# 256/256 [==============================] - 2s 10ms/step - loss: 0.7719 - mse: 1.9458 - mae: 0.7719 - mape: 47.7747 - val_loss: 0.8071 - val_mse: 1.9984 - val_mae: 0.8071 - val_mape: 47.5974
# Epoch 3/30
# 256/256 [==============================] - 2s 10ms/step - loss: 0.7150 - mse: 1.7425 - mae: 0.7150 - mape: 43.2260 - val_loss: 0.8290 - val_mse: 1.9675 - val_mae: 0.8290 - val_mape: 46.7607
# Epoch 4/30
# 256/256 [==============================] - 2s 10ms/step - loss: 0.6921 - mse: 1.6799 - mae: 0.6921 - mape: 41.7689 - val_loss: 0.8367 - val_mse: 1.9936 - val_mae: 0.8367 - val_mape: 46.4817
# Epoch 5/30
# 256/256 [==============================] - 2s 9ms/step - loss: 0.6800 - mse: 1.6431 - mae: 0.6800 - mape: 40.8977 - val_loss: 0.8439 - val_mse: 2.0019 - val_mae: 0.8439 - val_mape: 46.6216
# Epoch 6/30
# 256/256 [==============================] - 2s 10ms/step - loss: 0.6693 - mse: 1.6157 - mae: 0.6693 - mape: 40.2815 - val_loss: 0.8429 - val_mse: 2.0342 - val_mae: 0.8429 - val_mape: 46.7215
# Epoch 7/30
# 256/256 [==============================] - 2s 9ms/step - loss: 0.6616 - mse: 1.5859 - mae: 0.6616 - mape: 39.7075 - val_loss: 0.8432 - val_mse: 2.0279 - val_mae: 0.8432 - val_mape: 46.7690
# Epoch 8/30
# 256/256 [==============================] - 2s 9ms/step - loss: 0.6543 - mse: 1.5484 - mae: 0.6543 - mape: 39.1456 - val_loss: 0.8527 - val_mse: 2.0095 - val_mae: 0.8527 - val_mape: 46.6538
# Epoch 9/30
# 256/256 [==============================] - 2s 9ms/step - loss: 0.6446 - mse: 1.5090 - mae: 0.6446 - mape: 38.5430 - val_loss: 0.8601 - val_mse: 2.0217 - val_mae: 0.8601 - val_mape: 46.5877
# Epoch 10/30
# 256/256 [==============================] - 2s 9ms/step - loss: 0.6335 - mse: 1.4707 - mae: 0.6335 - mape: 37.8602 - val_loss: 0.8679 - val_mse: 2.0129 - val_mae: 0.8679 - val_mape: 46.4693
# Epoch 11/30
# 256/256 [==============================] - 2s 9ms/step - loss: 0.6250 - mse: 1.4300 - mae: 0.6250 - mape: 37.2272 - val_loss: 0.8692 - val_mse: 2.0473 - val_mae: 0.8692 - val_mape: 46.7676
# Epoch 12/30
# 256/256 [==============================] - 2s 9ms/step - loss: 0.6146 - mse: 1.4005 - mae: 0.6146 - mape: 36.6359 - val_loss: 0.8760 - val_mse: 2.0346 - val_mae: 0.8760 - val_mape: 46.6304
# Epoch 13/30
# 256/256 [==============================] - 2s 9ms/step - loss: 0.6069 - mse: 1.3665 - mae: 0.6069 - mape: 36.1078 - val_loss: 0.8803 - val_mse: 2.0536 - val_mae: 0.8803 - val_mape: 46.5799
# Epoch 14/30
# 256/256 [==============================] - 2s 9ms/step - loss: 0.5979 - mse: 1.3451 - mae: 0.5979 - mape: 35.6152 - val_loss: 0.8851 - val_mse: 2.0089 - val_mae: 0.8851 - val_mape: 46.4322
# Epoch 15/30
# 256/256 [==============================] - 2s 9ms/step - loss: 0.5913 - mse: 1.3218 - mae: 0.5913 - mape: 35.1957 - val_loss: 0.8855 - val_mse: 2.0350 - val_mae: 0.8855 - val_mape: 46.5649
# Epoch 16/30
# 256/256 [==============================] - 2s 9ms/step - loss: 0.5869 - mse: 1.3023 - mae: 0.5869 - mape: 34.8788 - val_loss: 0.8888 - val_mse: 2.0392 - val_mae: 0.8888 - val_mape: 46.6059
# Epoch 17/30
# 256/256 [==============================] - 2s 9ms/step - loss: 0.5810 - mse: 1.2848 - mae: 0.5810 - mape: 34.4829 - val_loss: 0.8967 - val_mse: 2.0596 - val_mae: 0.8967 - val_mape: 46.4328
# Epoch 18/30
# 256/256 [==============================] - 2s 9ms/step - loss: 0.5762 - mse: 1.2691 - mae: 0.5762 - mape: 34.2020 - val_loss: 0.8978 - val_mse: 2.0577 - val_mae: 0.8978 - val_mape: 46.6952
# Epoch 19/30
# 256/256 [==============================] - 2s 9ms/step - loss: 0.5704 - mse: 1.2565 - mae: 0.5704 - mape: 33.9342 - val_loss: 0.8954 - val_mse: 2.0459 - val_mae: 0.8954 - val_mape: 46.5997
# Epoch 20/30
# 256/256 [==============================] - 2s 9ms/step - loss: 0.5656 - mse: 1.2469 - mae: 0.5656 - mape: 33.6780 - val_loss: 0.8998 - val_mse: 2.0399 - val_mae: 0.8998 - val_mape: 46.4906
# Epoch 21/30
# 256/256 [==============================] - 2s 9ms/step - loss: 0.5623 - mse: 1.2365 - mae: 0.5623 - mape: 33.4756 - val_loss: 0.9061 - val_mse: 2.0729 - val_mae: 0.9061 - val_mape: 46.7302
# Epoch 22/30
# 256/256 [==============================] - 2s 9ms/step - loss: 0.5607 - mse: 1.2242 - mae: 0.5607 - mape: 33.2800 - val_loss: 0.9034 - val_mse: 2.0581 - val_mae: 0.9034 - val_mape: 46.5937
# Epoch 23/30
# 256/256 [==============================] - 2s 10ms/step - loss: 0.5567 - mse: 1.2151 - mae: 0.5567 - mape: 33.0796 - val_loss: 0.9045 - val_mse: 2.0518 - val_mae: 0.9045 - val_mape: 46.6387
# Epoch 24/30
# 256/256 [==============================] - 2s 9ms/step - loss: 0.5522 - mse: 1.2111 - mae: 0.5522 - mape: 32.9253 - val_loss: 0.9067 - val_mse: 2.0573 - val_mae: 0.9067 - val_mape: 46.5368
# Epoch 25/30
# 256/256 [==============================] - 2s 9ms/step - loss: 0.5499 - mse: 1.2025 - mae: 0.5499 - mape: 32.7538 - val_loss: 0.9039 - val_mse: 2.0494 - val_mae: 0.9039 - val_mape: 46.4510
# Epoch 26/30
# 256/256 [==============================] - 2s 10ms/step - loss: 0.5476 - mse: 1.1958 - mae: 0.5476 - mape: 32.6022 - val_loss: 0.9118 - val_mse: 2.0534 - val_mae: 0.9118 - val_mape: 46.5850
# Epoch 27/30
# 256/256 [==============================] - 2s 9ms/step - loss: 0.5461 - mse: 1.1917 - mae: 0.5461 - mape: 32.5113 - val_loss: 0.9140 - val_mse: 2.0339 - val_mae: 0.9140 - val_mape: 46.2593
# Epoch 28/30
# 256/256 [==============================] - 2s 9ms/step - loss: 0.5448 - mse: 1.1863 - mae: 0.5448 - mape: 32.3894 - val_loss: 0.9171 - val_mse: 2.0342 - val_mae: 0.9171 - val_mape: 46.4239
# Epoch 29/30
# 256/256 [==============================] - 2s 9ms/step - loss: 0.5426 - mse: 1.1799 - mae: 0.5426 - mape: 32.2832 - val_loss: 0.9124 - val_mse: 2.0412 - val_mae: 0.9124 - val_mape: 46.4687
# Epoch 30/30
# 256/256 [==============================] - 2s 9ms/step - loss: 0.5397 - mse: 1.1766 - mae: 0.5397 - mape: 32.1825 - val_loss: 0.9128 - val_mse: 2.0544 - val_mae: 0.9128 - val_mape: 46.4406

# %%
# scores = model.evaluate_generator(_evaluate_generator('train_whole_list_5s.txt','test_whole_list_5s.txt'),steps=134103)
# scores = model.evaluate_generator(_evaluate_generator('train_whole_list_10.txt','test_whole_list_10.txt'),steps=34266)
# scores = model.evaluate_generator(_evaluate_generator('train_whole_list_6s.txt','test_whole_list_6s.txt'),steps=134103)
scores = model.evaluate(test_data, test_target, steps=2500)
print(scores)
# Out:
# 2248/2500 [=========================>....] - ETA: 0s - loss: 0.9177 - mse: 2.0569 - mae: 0.9177 - mape: 47.2186WARNING:tensorflow:Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches (in this case, 2500 batches). You may need to use the repeat() function when building your dataset.
# 2500/2500 [==============================] - 7s 3ms/step - loss: 0.9176 - mse: 2.0562 - mae: 0.9176 - mape: 47.1971
# [0.9175692796707153, 2.056164264678955, 0.9175692796707153, 47.19711685180664]

# %%
#model.save(path+"IMDB_ADLFM_baseline")
